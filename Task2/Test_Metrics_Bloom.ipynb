# %%
import pandas as pd
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from rouge_score import rouge_scorer
from pycocoevalcap.cider.cider import Cider

# %%
df1 = pd.read_csv('output_bloom.csv')
df2 = pd.read_csv('test_df.csv')

# %%
df1 = df1['content'].tolist()
df2 = df2['content'].tolist()

# %%
len(df1)
# Out:
# 500

# %%
df2 = df2[:500]
len(df2)
# Out:
# 500

# %%
def calculate_bleu(reference, candidate):
    smooth = SmoothingFunction().method4
    bleu_1 = sentence_bleu([reference], candidate, weights=(1, 0, 0, 0), smoothing_function=smooth)
    bleu_2 = sentence_bleu([reference], candidate, weights=(0.5, 0.5, 0, 0), smoothing_function=smooth)
    bleu_3 = sentence_bleu([reference], candidate, weights=(0.33, 0.33, 0.33, 0), smoothing_function=smooth)
    bleu_4 = sentence_bleu([reference], candidate, weights=(0.25, 0.25, 0.25, 0.25), smoothing_function=smooth)
    return bleu_1, bleu_2, bleu_3, bleu_4

rouge_scorer_obj = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
cider_scorer = Cider()

# %%
bleu_scores = []
rouge_scores = []
cider_scores = []

# %%
for ref, cand in zip(df1, df2):
    # Tokenize reference and candidate texts
    ref_tokens = ref.split()
    cand_tokens = cand.split()

    # Calculate BLEU scores
    bleu_1, bleu_2, bleu_3, bleu_4 = calculate_bleu(ref_tokens, cand_tokens)
    bleu_scores.append((bleu_1, bleu_2, bleu_3, bleu_4))

    # Calculate ROUGE scores
    rouge_scores_sample = rouge_scorer_obj.score(ref, cand)
    rouge_scores.append(rouge_scores_sample)

    # Calculate CIDEr scores (CIDEr works with the format {idx: [text]})
    cider_score, _ = cider_scorer.compute_score({0: [ref]}, {0: [cand]})
    cider_scores.append(cider_score)

# %%
for i in range(len(df1)):
    print(f"Sample {i+1}:")
    print(f"BLEU-1: {bleu_scores[i][0]:.4f}, BLEU-2: {bleu_scores[i][1]:.4f}, BLEU-3: {bleu_scores[i][2]:.4f}, BLEU-4: {bleu_scores[i][3]:.4f}")
    print(f"ROUGE-1: {rouge_scores[i]['rouge1'].fmeasure:.4f}, ROUGE-2: {rouge_scores[i]['rouge2'].fmeasure:.4f}, ROUGE-L: {rouge_scores[i]['rougeL'].fmeasure:.4f}")
    print(f"CIDEr: {cider_scores[i]:.4f}\n")
# Out:
# Sample 1:
# BLEU-1: 0.3951, BLEU-2: 0.3951, BLEU-3: 0.3951, BLEU-4: 0.3951
# ROUGE-1: 0.6977, ROUGE-2: 0.6829, ROUGE-L: 0.6977
# CIDEr: 0.0000
#
# Sample 2:
# BLEU-1: 0.6575, BLEU-2: 0.6575, BLEU-3: 0.6575, BLEU-4: 0.6575
# ROUGE-1: 0.8169, ROUGE-2: 0.8116, ROUGE-L: 0.8169
# CIDEr: 0.0000
#
# Sample 3:
# BLEU-1: 0.4204, BLEU-2: 0.4204, BLEU-3: 0.4204, BLEU-4: 0.4204
# ROUGE-1: 0.6977, ROUGE-2: 0.6829, ROUGE-L: 0.6977
# CIDEr: 0.0000
#
# Sample 4:
# BLEU-1: 0.5220, BLEU-2: 0.5220, BLEU-3: 0.5220, BLEU-4: 0.5220
# ROUGE-1: 0.7547, ROUGE-2: 0.7451, ROUGE-L: 0.7547
# CIDEr: 0.0000
#
# Sample 5:
# BLEU-1: 0.6286, BLEU-2: 0.6286, BLEU-3: 0.6286, BLEU-4: 0.6286
# ROUGE-1: 0.8000, ROUGE-2: 0.7937, ROUGE-L: 0.8000
# CIDEr: 0.0000
#
# Sample 6:
# BLEU-1: 0.6179, BLEU-2: 0.6179, BLEU-3: 0.6179, BLEU-4: 0.6179
# ROUGE-1: 0.8000, ROUGE-2: 0.7937, ROUGE-L: 0.8000
# CIDEr: 0.0000
#
# Sample 7:
# BLEU-1: 0.3385, BLEU-2: 0.3385, BLEU-3: 0.3385, BLEU-4: 0.3385
# ROUGE-1: 0.6486, ROUGE-2: 0.6286, ROUGE-L: 0.6486
# CIDEr: 0.0000
#
# Sample 8:
# BLEU-1: 0.3067, BLEU-2: 0.3067, BLEU-3: 0.3067, BLEU-4: 0.3067
# ROUGE-1: 0.6286, ROUGE-2: 0.6061, ROUGE-L: 0.6286
# CIDEr: 0.0000
#
# Sample 9:
# BLEU-1: 0.2725, BLEU-2: 0.2725, BLEU-3: 0.2725, BLEU-4: 0.2725
# ROUGE-1: 0.6286, ROUGE-2: 0.6061, ROUGE-L: 0.6286
# CIDEr: 0.0000
#
# Sample 10:
# BLEU-1: 0.7225, BLEU-2: 0.7225, BLEU-3: 0.7225, BLEU-4: 0.7225
# ROUGE-1: 0.8660, ROUGE-2: 0.8632, ROUGE-L: 0.8660
# CIDEr: 0.0000
#
# Sample 11:
# BLEU-1: 0.6575, BLEU-2: 0.6575, BLEU-3: 0.6575, BLEU-4: 0.6575
# ROUGE-1: 0.8267, ROUGE-2: 0.8219, ROUGE-L: 0.8267
# CIDEr: 0.0000
#
# Sample 12:
# BLEU-1: 0.4857, BLEU-2: 0.4857, BLEU-3: 0.4857, BLEU-4: 0.4857
# ROUGE-1: 0.7451, ROUGE-2: 0.7347, ROUGE-L: 0.7451
# CIDEr: 0.0000
#
# Sample 13:
# BLEU-1: 0.6575, BLEU-2: 0.6575, BLEU-3: 0.6575, BLEU-4: 0.6575
# ROUGE-1: 0.8267, ROUGE-2: 0.8219, ROUGE-L: 0.8267
# CIDEr: 0.0000
#
# Sample 14:
# BLEU-1: 0.6065, BLEU-2: 0.6065, BLEU-3: 0.6065, BLEU-4: 0.6065
# ROUGE-1: 0.8000, ROUGE-2: 0.7937, ROUGE-L: 0.8000
# CIDEr: 0.0000
#
# Sample 15:
# BLEU-1: 0.5538, BLEU-2: 0.5538, BLEU-3: 0.5538, BLEU-4: 0.5538
# ROUGE-1: 0.7869, ROUGE-2: 0.7797, ROUGE-L: 0.7869
# CIDEr: 0.0000
#
# Sample 16:
# BLEU-1: 0.6286, BLEU-2: 0.6286, BLEU-3: 0.6286, BLEU-4: 0.6286
# ROUGE-1: 0.8219, ROUGE-2: 0.8169, ROUGE-L: 0.8219
# CIDEr: 0.0000
#
# Sample 17:
# BLEU-1: 0.6065, BLEU-2: 0.6065, BLEU-3: 0.6065, BLEU-4: 0.6065
# ROUGE-1: 0.7869, ROUGE-2: 0.7797, ROUGE-L: 0.7869
# CIDEr: 0.0000
#
# Sample 18:
# BLEU-1: 0.4204, BLEU-2: 0.4204, BLEU-3: 0.4204, BLEU-4: 0.4204
# ROUGE-1: 0.6977, ROUGE-2: 0.6829, ROUGE-L: 0.6977
# CIDEr: 0.0000
#
# Sample 19:
# BLEU-1: 0.3067, BLEU-2: 0.3067, BLEU-3: 0.3067, BLEU-4: 0.3067
# ROUGE-1: 0.6486, ROUGE-2: 0.6286, ROUGE-L: 0.6486
# CIDEr: 0.0000
#
# Sample 20:
# BLEU-1: 0.6483, BLEU-2: 0.6483, BLEU-3: 0.6483, BLEU-4: 0.6483
# ROUGE-1: 0.8312, ROUGE-2: 0.8267, ROUGE-L: 0.8312
# CIDEr: 0.0000
#
# Sample 21:
# BLEU-1: 0.6823, BLEU-2: 0.6823, BLEU-3: 0.6823, BLEU-4: 0.6823
# ROUGE-1: 0.8471, ROUGE-2: 0.8434, ROUGE-L: 0.8471
# CIDEr: 0.0000
#
# Sample 22:
# BLEU-1: 0.5045, BLEU-2: 0.5045, BLEU-3: 0.5045, BLEU-4: 0.5045
# ROUGE-1: 0.7451, ROUGE-2: 0.7347, ROUGE-L: 0.7451
# CIDEr: 0.0000
#
# Sample 23:
# BLEU-1: 0.7391, BLEU-2: 0.7391, BLEU-3: 0.7391, BLEU-4: 0.7391
# ROUGE-1: 0.8687, ROUGE-2: 0.8660, ROUGE-L: 0.8687
# CIDEr: 0.0000
#
# Sample 24:
# BLEU-1: 0.2725, BLEU-2: 0.2725, BLEU-3: 0.2725, BLEU-4: 0.2725
# ROUGE-1: 0.6061, ROUGE-2: 0.5806, ROUGE-L: 0.6061
# CIDEr: 0.0000
#
# Sample 25:
# BLEU-1: 0.3679, BLEU-2: 0.3679, BLEU-3: 0.3679, BLEU-4: 0.3679
# ROUGE-1: 0.6829, ROUGE-2: 0.6667, ROUGE-L: 0.6829
# CIDEr: 0.0000
#
# Sample 26:
# BLEU-1: 0.0388, BLEU-2: 0.0388, BLEU-3: 0.0388, BLEU-4: 0.0388
# ROUGE-1: 0.3810, ROUGE-2: 0.3158, ROUGE-L: 0.3810
# CIDEr: 0.0000
#
# Sample 27:
# BLEU-1: 0.2359, BLEU-2: 0.2359, BLEU-3: 0.2359, BLEU-4: 0.2359
# ROUGE-1: 0.6061, ROUGE-2: 0.5806, ROUGE-L: 0.6061
# CIDEr: 0.0000
#
# Sample 28:
# BLEU-1: 0.6744, BLEU-2: 0.6744, BLEU-3: 0.6744, BLEU-4: 0.6744
# ROUGE-1: 0.8395, ROUGE-2: 0.8354, ROUGE-L: 0.8395
# CIDEr: 0.0000
#
# Sample 29:
# BLEU-1: 0.7037, BLEU-2: 0.7037, BLEU-3: 0.7037, BLEU-4: 0.7037
# ROUGE-1: 0.8571, ROUGE-2: 0.8539, ROUGE-L: 0.8571
# CIDEr: 0.0000
#
# Sample 30:
# BLEU-1: 0.2725, BLEU-2: 0.2725, BLEU-3: 0.2725, BLEU-4: 0.2725
# ROUGE-1: 0.6061, ROUGE-2: 0.5806, ROUGE-L: 0.6061
# CIDEr: 0.0000
#
# Sample 31:
# BLEU-1: 0.2359, BLEU-2: 0.2359, BLEU-3: 0.2359, BLEU-4: 0.2359
# ROUGE-1: 0.5806, ROUGE-2: 0.5517, ROUGE-L: 0.5806
# CIDEr: 0.0000
#
# Sample 32:
# BLEU-1: 0.2725, BLEU-2: 0.2725, BLEU-3: 0.2725, BLEU-4: 0.2725
# ROUGE-1: 0.5806, ROUGE-2: 0.5517, ROUGE-L: 0.5806
# CIDEr: 0.0000
#
# Sample 33:
# BLEU-1: 0.5682, BLEU-2: 0.5682, BLEU-3: 0.5682, BLEU-4: 0.5682
# ROUGE-1: 0.7797, ROUGE-2: 0.7719, ROUGE-L: 0.7797
# CIDEr: 0.0000
#
# Sample 34:
# BLEU-1: 0.3385, BLEU-2: 0.3385, BLEU-3: 0.3385, BLEU-4: 0.3385
# ROUGE-1: 0.6486, ROUGE-2: 0.6286, ROUGE-L: 0.6486
# CIDEr: 0.0000
#
# Sample 35:
# BLEU-1: 0.4437, BLEU-2: 0.4437, BLEU-3: 0.4437, BLEU-4: 0.4437
# ROUGE-1: 0.7347, ROUGE-2: 0.7234, ROUGE-L: 0.7347
# CIDEr: 0.0000
#
# Sample 36:
# BLEU-1: 0.4857, BLEU-2: 0.4857, BLEU-3: 0.4857, BLEU-4: 0.4857
# ROUGE-1: 0.7234, ROUGE-2: 0.7111, ROUGE-L: 0.7234
# CIDEr: 0.0000
#
# Sample 37:
# BLEU-1: 0.5538, BLEU-2: 0.5538, BLEU-3: 0.5538, BLEU-4: 0.5538
# ROUGE-1: 0.7719, ROUGE-2: 0.7636, ROUGE-L: 0.7719
# CIDEr: 0.0000
#
# Sample 38:
# BLEU-1: 0.4204, BLEU-2: 0.4204, BLEU-3: 0.4204, BLEU-4: 0.4204
# ROUGE-1: 0.6977, ROUGE-2: 0.6829, ROUGE-L: 0.6977
# CIDEr: 0.0000
#
# Sample 39:
# BLEU-1: 0.3385, BLEU-2: 0.3385, BLEU-3: 0.3385, BLEU-4: 0.3385
# ROUGE-1: 0.6486, ROUGE-2: 0.6286, ROUGE-L: 0.6486
# CIDEr: 0.0000
#
# Sample 40:
# BLEU-1: 0.2359, BLEU-2: 0.2359, BLEU-3: 0.2359, BLEU-4: 0.2359
# ROUGE-1: 0.6286, ROUGE-2: 0.6061, ROUGE-L: 0.6286
# CIDEr: 0.0000
#
# Sample 41:
# BLEU-1: 0.3679, BLEU-2: 0.3679, BLEU-3: 0.3679, BLEU-4: 0.3679
# ROUGE-1: 0.6486, ROUGE-2: 0.6286, ROUGE-L: 0.6486
# CIDEr: 0.0000
#
# Sample 42:
# BLEU-1: 0.5220, BLEU-2: 0.5220, BLEU-3: 0.5220, BLEU-4: 0.5220
# ROUGE-1: 0.7636, ROUGE-2: 0.7547, ROUGE-L: 0.7636
# CIDEr: 0.0000
#
# Sample 43:
# BLEU-1: 0.3385, BLEU-2: 0.3385, BLEU-3: 0.3385, BLEU-4: 0.3385
# ROUGE-1: 0.6667, ROUGE-2: 0.6486, ROUGE-L: 0.6667
# CIDEr: 0.0000
#
# Sample 44:
# BLEU-1: 0.2725, BLEU-2: 0.2725, BLEU-3: 0.2725, BLEU-4: 0.2725
# ROUGE-1: 0.6061, ROUGE-2: 0.5806, ROUGE-L: 0.6061
# CIDEr: 0.0000
#
# Sample 45:
# BLEU-1: 0.7442, BLEU-2: 0.7442, BLEU-3: 0.7442, BLEU-4: 0.7442
# ROUGE-1: 0.8762, ROUGE-2: 0.8738, ROUGE-L: 0.8762
# CIDEr: 0.0000
#
# Sample 46:
# BLEU-1: 0.6969, BLEU-2: 0.6969, BLEU-3: 0.6969, BLEU-4: 0.6969
# ROUGE-1: 0.8506, ROUGE-2: 0.8471, ROUGE-L: 0.8506
# CIDEr: 0.0000
#
# Sample 47:
# BLEU-1: 0.7338, BLEU-2: 0.7338, BLEU-3: 0.7338, BLEU-4: 0.7338
# ROUGE-1: 0.8713, ROUGE-2: 0.8687, ROUGE-L: 0.8713
# CIDEr: 0.0000
#
# Sample 48:
# BLEU-1: 0.5818, BLEU-2: 0.5818, BLEU-3: 0.5818, BLEU-4: 0.5818
# ROUGE-1: 0.7869, ROUGE-2: 0.7797, ROUGE-L: 0.7869
# CIDEr: 0.0000
#
# Sample 49:
# BLEU-1: 0.4857, BLEU-2: 0.4857, BLEU-3: 0.4857, BLEU-4: 0.4857
# ROUGE-1: 0.7234, ROUGE-2: 0.7111, ROUGE-L: 0.7234
# CIDEr: 0.0000
#
# Sample 50:
# BLEU-1: 0.7103, BLEU-2: 0.7103, BLEU-3: 0.7103, BLEU-4: 0.7103
# ROUGE-1: 0.8632, ROUGE-2: 0.8602, ROUGE-L: 0.8632
# CIDEr: 0.0000
#
# Sample 51:
# BLEU-1: 0.5045, BLEU-2: 0.5045, BLEU-3: 0.5045, BLEU-4: 0.5045
# ROUGE-1: 0.7547, ROUGE-2: 0.7451, ROUGE-L: 0.7547
# CIDEr: 0.0000
#
# Sample 52:
# BLEU-1: 0.2725, BLEU-2: 0.2725, BLEU-3: 0.2725, BLEU-4: 0.2725
# ROUGE-1: 0.6286, ROUGE-2: 0.6061, ROUGE-L: 0.6286
# CIDEr: 0.0000
#
# Sample 53:
# BLEU-1: 0.4437, BLEU-2: 0.4437, BLEU-3: 0.4437, BLEU-4: 0.4437
# ROUGE-1: 0.7111, ROUGE-2: 0.6977, ROUGE-L: 0.7111
# CIDEr: 0.0000
#
# Sample 54:
# BLEU-1: 0.5682, BLEU-2: 0.5682, BLEU-3: 0.5682, BLEU-4: 0.5682
# ROUGE-1: 0.7869, ROUGE-2: 0.7797, ROUGE-L: 0.7869
# CIDEr: 0.0000
#
# Sample 55:
# BLEU-1: 0.2359, BLEU-2: 0.2359, BLEU-3: 0.2359, BLEU-4: 0.2359
# ROUGE-1: 0.6061, ROUGE-2: 0.5806, ROUGE-L: 0.6061
# CIDEr: 0.0000
#
# Sample 56:
# BLEU-1: 0.6897, BLEU-2: 0.6897, BLEU-3: 0.6897, BLEU-4: 0.6897
# ROUGE-1: 0.8395, ROUGE-2: 0.8354, ROUGE-L: 0.8395
# CIDEr: 0.0000
#
# Sample 57:
# BLEU-1: 0.7103, BLEU-2: 0.7103, BLEU-3: 0.7103, BLEU-4: 0.7103
# ROUGE-1: 0.8602, ROUGE-2: 0.8571, ROUGE-L: 0.8602
# CIDEr: 0.0000
#
# Sample 58:
# BLEU-1: 0.6897, BLEU-2: 0.6897, BLEU-3: 0.6897, BLEU-4: 0.6897
# ROUGE-1: 0.8471, ROUGE-2: 0.8434, ROUGE-L: 0.8471
# CIDEr: 0.0000
#
# Sample 59:
# BLEU-1: 0.5818, BLEU-2: 0.5818, BLEU-3: 0.5818, BLEU-4: 0.5818
# ROUGE-1: 0.7797, ROUGE-2: 0.7719, ROUGE-L: 0.7797
# CIDEr: 0.0000
#
# Sample 60:
# BLEU-1: 0.5538, BLEU-2: 0.5538, BLEU-3: 0.5538, BLEU-4: 0.5538
# ROUGE-1: 0.7719, ROUGE-2: 0.7636, ROUGE-L: 0.7719
# CIDEr: 0.0000
#
# Sample 61:
# BLEU-1: 0.4437, BLEU-2: 0.4437, BLEU-3: 0.4437, BLEU-4: 0.4437
# ROUGE-1: 0.7234, ROUGE-2: 0.7111, ROUGE-L: 0.7234
# CIDEr: 0.0000
#
# Sample 62:
# BLEU-1: 0.6661, BLEU-2: 0.6661, BLEU-3: 0.6661, BLEU-4: 0.6661
# ROUGE-1: 0.8312, ROUGE-2: 0.8267, ROUGE-L: 0.8312
# CIDEr: 0.0000
#
# Sample 63:
# BLEU-1: 0.6065, BLEU-2: 0.6065, BLEU-3: 0.6065, BLEU-4: 0.6065
# ROUGE-1: 0.8000, ROUGE-2: 0.7937, ROUGE-L: 0.8000
# CIDEr: 0.0000
#
# Sample 64:
# BLEU-1: 0.5538, BLEU-2: 0.5538, BLEU-3: 0.5538, BLEU-4: 0.5538
# ROUGE-1: 0.7719, ROUGE-2: 0.7636, ROUGE-L: 0.7719
# CIDEr: 0.0000
#
# Sample 65:
# BLEU-1: 0.3385, BLEU-2: 0.3385, BLEU-3: 0.3385, BLEU-4: 0.3385
# ROUGE-1: 0.6486, ROUGE-2: 0.6286, ROUGE-L: 0.6486
# CIDEr: 0.0000
#
# Sample 66:
# BLEU-1: 0.4655, BLEU-2: 0.4655, BLEU-3: 0.4655, BLEU-4: 0.4655
# ROUGE-1: 0.7111, ROUGE-2: 0.6977, ROUGE-L: 0.7111
# CIDEr: 0.0000
#
# Sample 67:
# BLEU-1: 0.7711, BLEU-2: 0.7711, BLEU-3: 0.7711, BLEU-4: 0.7711
# ROUGE-1: 0.8850, ROUGE-2: 0.8829, ROUGE-L: 0.8850
# CIDEr: 0.0000
#
# Sample 68:
# BLEU-1: 0.6575, BLEU-2: 0.6575, BLEU-3: 0.6575, BLEU-4: 0.6575
# ROUGE-1: 0.8267, ROUGE-2: 0.8219, ROUGE-L: 0.8267
# CIDEr: 0.0000
#
# Sample 69:
# BLEU-1: 0.1969, BLEU-2: 0.1969, BLEU-3: 0.1969, BLEU-4: 0.1969
# ROUGE-1: 0.5517, ROUGE-2: 0.5185, ROUGE-L: 0.5517
# CIDEr: 0.0000
#
# Sample 70:
# BLEU-1: 0.6065, BLEU-2: 0.6065, BLEU-3: 0.6065, BLEU-4: 0.6065
# ROUGE-1: 0.8060, ROUGE-2: 0.8000, ROUGE-L: 0.8060
# CIDEr: 0.0000
#
# Sample 71:
# BLEU-1: 0.4857, BLEU-2: 0.4857, BLEU-3: 0.4857, BLEU-4: 0.4857
# ROUGE-1: 0.7451, ROUGE-2: 0.7347, ROUGE-L: 0.7451
# CIDEr: 0.0000
#
# Sample 72:
# BLEU-1: 0.6286, BLEU-2: 0.6286, BLEU-3: 0.6286, BLEU-4: 0.6286
# ROUGE-1: 0.8169, ROUGE-2: 0.8116, ROUGE-L: 0.8169
# CIDEr: 0.0000
#
# Sample 73:
# BLEU-1: 0.4437, BLEU-2: 0.4437, BLEU-3: 0.4437, BLEU-4: 0.4437
# ROUGE-1: 0.6977, ROUGE-2: 0.6829, ROUGE-L: 0.6977
# CIDEr: 0.0000
#
# Sample 74:
# BLEU-1: 0.3679, BLEU-2: 0.3679, BLEU-3: 0.3679, BLEU-4: 0.3679
# ROUGE-1: 0.6667, ROUGE-2: 0.6486, ROUGE-L: 0.6667
# CIDEr: 0.0000
#
# Sample 75:
# BLEU-1: 0.6969, BLEU-2: 0.6969, BLEU-3: 0.6969, BLEU-4: 0.6969
# ROUGE-1: 0.8660, ROUGE-2: 0.8632, ROUGE-L: 0.8660
# CIDEr: 0.0000
#
# Sample 76:
# BLEU-1: 0.7037, BLEU-2: 0.7037, BLEU-3: 0.7037, BLEU-4: 0.7037
# ROUGE-1: 0.8506, ROUGE-2: 0.8471, ROUGE-L: 0.8506
# CIDEr: 0.0000
#
# Sample 77:
# BLEU-1: 0.6286, BLEU-2: 0.6286, BLEU-3: 0.6286, BLEU-4: 0.6286
# ROUGE-1: 0.8169, ROUGE-2: 0.8116, ROUGE-L: 0.8169
# CIDEr: 0.0000
#
# Sample 78:
# BLEU-1: 0.2725, BLEU-2: 0.2725, BLEU-3: 0.2725, BLEU-4: 0.2725
# ROUGE-1: 0.5806, ROUGE-2: 0.5517, ROUGE-L: 0.5806
# CIDEr: 0.0000
#
# Sample 79:
# BLEU-1: 0.5220, BLEU-2: 0.5220, BLEU-3: 0.5220, BLEU-4: 0.5220
# ROUGE-1: 0.7719, ROUGE-2: 0.7636, ROUGE-L: 0.7719
# CIDEr: 0.0000
#
# Sample 80:
# BLEU-1: 0.3951, BLEU-2: 0.3951, BLEU-3: 0.3951, BLEU-4: 0.3951
# ROUGE-1: 0.6829, ROUGE-2: 0.6667, ROUGE-L: 0.6829
# CIDEr: 0.0000
#
# Sample 81:
# BLEU-1: 0.3679, BLEU-2: 0.3679, BLEU-3: 0.3679, BLEU-4: 0.3679
# ROUGE-1: 0.6667, ROUGE-2: 0.6486, ROUGE-L: 0.6667
# CIDEr: 0.0000
#
# Sample 82:
# BLEU-1: 0.2359, BLEU-2: 0.2359, BLEU-3: 0.2359, BLEU-4: 0.2359
# ROUGE-1: 0.5806, ROUGE-2: 0.5517, ROUGE-L: 0.5806
# CIDEr: 0.0000
#
# Sample 83:
# BLEU-1: 0.7037, BLEU-2: 0.7037, BLEU-3: 0.7037, BLEU-4: 0.7037
# ROUGE-1: 0.8539, ROUGE-2: 0.8506, ROUGE-L: 0.8539
# CIDEr: 0.0000
#
# Sample 84:
# BLEU-1: 0.6387, BLEU-2: 0.6387, BLEU-3: 0.6387, BLEU-4: 0.6387
# ROUGE-1: 0.8219, ROUGE-2: 0.8169, ROUGE-L: 0.8219
# CIDEr: 0.0000
#
# Sample 85:
# BLEU-1: 0.1146, BLEU-2: 0.1146, BLEU-3: 0.1146, BLEU-4: 0.1146
# ROUGE-1: 0.4800, ROUGE-2: 0.4348, ROUGE-L: 0.4800
# CIDEr: 0.0000
#
# Sample 86:
# BLEU-1: 0.6575, BLEU-2: 0.6575, BLEU-3: 0.6575, BLEU-4: 0.6575
# ROUGE-1: 0.8312, ROUGE-2: 0.8267, ROUGE-L: 0.8312
# CIDEr: 0.0000
#
# Sample 87:
# BLEU-1: 0.1561, BLEU-2: 0.1561, BLEU-3: 0.1561, BLEU-4: 0.1561
# ROUGE-1: 0.4800, ROUGE-2: 0.4348, ROUGE-L: 0.4800
# CIDEr: 0.0000
#
# Sample 88:
# BLEU-1: 0.3067, BLEU-2: 0.3067, BLEU-3: 0.3067, BLEU-4: 0.3067
# ROUGE-1: 0.6486, ROUGE-2: 0.6286, ROUGE-L: 0.6486
# CIDEr: 0.0000
#
# Sample 89:
# BLEU-1: 0.6179, BLEU-2: 0.6179, BLEU-3: 0.6179, BLEU-4: 0.6179
# ROUGE-1: 0.8060, ROUGE-2: 0.8000, ROUGE-L: 0.8060
# CIDEr: 0.0000
#
# Sample 90:
# BLEU-1: 0.3385, BLEU-2: 0.3385, BLEU-3: 0.3385, BLEU-4: 0.3385
# ROUGE-1: 0.6667, ROUGE-2: 0.6486, ROUGE-L: 0.6667
# CIDEr: 0.0000
#
# Sample 91:
# BLEU-1: 0.5045, BLEU-2: 0.5045, BLEU-3: 0.5045, BLEU-4: 0.5045
# ROUGE-1: 0.7451, ROUGE-2: 0.7347, ROUGE-L: 0.7451
# CIDEr: 0.0000
#
# Sample 92:
# BLEU-1: 0.5682, BLEU-2: 0.5682, BLEU-3: 0.5682, BLEU-4: 0.5682
# ROUGE-1: 0.7797, ROUGE-2: 0.7719, ROUGE-L: 0.7797
# CIDEr: 0.0000
#
# Sample 93:
# BLEU-1: 0.7225, BLEU-2: 0.7225, BLEU-3: 0.7225, BLEU-4: 0.7225
# ROUGE-1: 0.8602, ROUGE-2: 0.8571, ROUGE-L: 0.8602
# CIDEr: 0.0000
#
# Sample 94:
# BLEU-1: 0.7037, BLEU-2: 0.7037, BLEU-3: 0.7037, BLEU-4: 0.7037
# ROUGE-1: 0.8571, ROUGE-2: 0.8539, ROUGE-L: 0.8571
# CIDEr: 0.0000
#
# Sample 95:
# BLEU-1: 0.6065, BLEU-2: 0.6065, BLEU-3: 0.6065, BLEU-4: 0.6065
# ROUGE-1: 0.8000, ROUGE-2: 0.7937, ROUGE-L: 0.8000
# CIDEr: 0.0000
#
# Sample 96:
# BLEU-1: 0.6969, BLEU-2: 0.6969, BLEU-3: 0.6969, BLEU-4: 0.6969
# ROUGE-1: 0.8471, ROUGE-2: 0.8434, ROUGE-L: 0.8471
# CIDEr: 0.0000
#
# Sample 97:
# BLEU-1: 0.2725, BLEU-2: 0.2725, BLEU-3: 0.2725, BLEU-4: 0.2725
# ROUGE-1: 0.6486, ROUGE-2: 0.6286, ROUGE-L: 0.6486
# CIDEr: 0.0000
#
# Sample 98:
# BLEU-1: 0.4857, BLEU-2: 0.4857, BLEU-3: 0.4857, BLEU-4: 0.4857
# ROUGE-1: 0.7234, ROUGE-2: 0.7111, ROUGE-L: 0.7234
# CIDEr: 0.0000
#
# Sample 99:
# BLEU-1: 0.3385, BLEU-2: 0.3385, BLEU-3: 0.3385, BLEU-4: 0.3385
# ROUGE-1: 0.6286, ROUGE-2: 0.6061, ROUGE-L: 0.6286
# CIDEr: 0.0000
#
# Sample 100:
# BLEU-1: 0.4437, BLEU-2: 0.4437, BLEU-3: 0.4437, BLEU-4: 0.4437
# ROUGE-1: 0.7234, ROUGE-2: 0.7111, ROUGE-L: 0.7234
# CIDEr: 0.0000
#
# Sample 101:
# BLEU-1: 0.4204, BLEU-2: 0.4204, BLEU-3: 0.4204, BLEU-4: 0.4204
# ROUGE-1: 0.6977, ROUGE-2: 0.6829, ROUGE-L: 0.6977
# CIDEr: 0.0000
#
# Sample 102:
# BLEU-1: 0.2725, BLEU-2: 0.2725, BLEU-3: 0.2725, BLEU-4: 0.2725
# ROUGE-1: 0.6286, ROUGE-2: 0.6061, ROUGE-L: 0.6286
# CIDEr: 0.0000
#
# Sample 103:
# BLEU-1: 0.7165, BLEU-2: 0.7165, BLEU-3: 0.7165, BLEU-4: 0.7165
# ROUGE-1: 0.8602, ROUGE-2: 0.8571, ROUGE-L: 0.8602
# CIDEr: 0.0000
#
# Sample 104:
# BLEU-1: 0.5385, BLEU-2: 0.5385, BLEU-3: 0.5385, BLEU-4: 0.5385
# ROUGE-1: 0.7797, ROUGE-2: 0.7719, ROUGE-L: 0.7797
# CIDEr: 0.0000
#
# Sample 105:
# BLEU-1: 0.2359, BLEU-2: 0.2359, BLEU-3: 0.2359, BLEU-4: 0.2359
# ROUGE-1: 0.5806, ROUGE-2: 0.5517, ROUGE-L: 0.5806
# CIDEr: 0.0000
#
# Sample 106:
# BLEU-1: 0.5220, BLEU-2: 0.5220, BLEU-3: 0.5220, BLEU-4: 0.5220
# ROUGE-1: 0.7547, ROUGE-2: 0.7451, ROUGE-L: 0.7547
# CIDEr: 0.0000
#
# Sample 107:
# BLEU-1: 0.3385, BLEU-2: 0.3385, BLEU-3: 0.3385, BLEU-4: 0.3385
# ROUGE-1: 0.6977, ROUGE-2: 0.6829, ROUGE-L: 0.6977
# CIDEr: 0.0000
#
# Sample 108:
# BLEU-1: 0.6575, BLEU-2: 0.6575, BLEU-3: 0.6575, BLEU-4: 0.6575
# ROUGE-1: 0.8312, ROUGE-2: 0.8267, ROUGE-L: 0.8312
# CIDEr: 0.0000
#
# Sample 109:
# BLEU-1: 0.4437, BLEU-2: 0.4437, BLEU-3: 0.4437, BLEU-4: 0.4437
# ROUGE-1: 0.7111, ROUGE-2: 0.6977, ROUGE-L: 0.7111
# CIDEr: 0.0000
#
# Sample 110:
# BLEU-1: 0.0743, BLEU-2: 0.0743, BLEU-3: 0.0743, BLEU-4: 0.0743
# ROUGE-1: 0.4348, ROUGE-2: 0.3810, ROUGE-L: 0.4348
# CIDEr: 0.0000
#
# Sample 111:
# BLEU-1: 0.6286, BLEU-2: 0.6286, BLEU-3: 0.6286, BLEU-4: 0.6286
# ROUGE-1: 0.8116, ROUGE-2: 0.8060, ROUGE-L: 0.8116
# CIDEr: 0.0000
#
# Sample 112:
# BLEU-1: 0.7103, BLEU-2: 0.7103, BLEU-3: 0.7103, BLEU-4: 0.7103
# ROUGE-1: 0.8539, ROUGE-2: 0.8506, ROUGE-L: 0.8539
# CIDEr: 0.0000
#
# Sample 113:
# BLEU-1: 0.5945, BLEU-2: 0.5945, BLEU-3: 0.5945, BLEU-4: 0.5945
# ROUGE-1: 0.7937, ROUGE-2: 0.7869, ROUGE-L: 0.7937
# CIDEr: 0.0000
#
# Sample 114:
# BLEU-1: 0.5385, BLEU-2: 0.5385, BLEU-3: 0.5385, BLEU-4: 0.5385
# ROUGE-1: 0.7636, ROUGE-2: 0.7547, ROUGE-L: 0.7636
# CIDEr: 0.0000
#
# Sample 115:
# BLEU-1: 0.2725, BLEU-2: 0.2725, BLEU-3: 0.2725, BLEU-4: 0.2725
# ROUGE-1: 0.6061, ROUGE-2: 0.5806, ROUGE-L: 0.6061
# CIDEr: 0.0000
#
# Sample 116:
# BLEU-1: 0.6969, BLEU-2: 0.6969, BLEU-3: 0.6969, BLEU-4: 0.6969
# ROUGE-1: 0.8471, ROUGE-2: 0.8434, ROUGE-L: 0.8471
# CIDEr: 0.0000
#
# Sample 117:
# BLEU-1: 0.6387, BLEU-2: 0.6387, BLEU-3: 0.6387, BLEU-4: 0.6387
# ROUGE-1: 0.8116, ROUGE-2: 0.8060, ROUGE-L: 0.8116
# CIDEr: 0.0000
#
# Sample 118:
# BLEU-1: 0.7165, BLEU-2: 0.7165, BLEU-3: 0.7165, BLEU-4: 0.7165
# ROUGE-1: 0.8660, ROUGE-2: 0.8632, ROUGE-L: 0.8660
# CIDEr: 0.0000
#
# Sample 119:
# BLEU-1: 0.4437, BLEU-2: 0.4437, BLEU-3: 0.4437, BLEU-4: 0.4437
# ROUGE-1: 0.7111, ROUGE-2: 0.6977, ROUGE-L: 0.7111
# CIDEr: 0.0000
#
# Sample 120:
# BLEU-1: 0.7825, BLEU-2: 0.7825, BLEU-3: 0.7825, BLEU-4: 0.7825
# ROUGE-1: 0.8943, ROUGE-2: 0.8926, ROUGE-L: 0.8943
# CIDEr: 0.0000
#
# Sample 121:
# BLEU-1: 0.7584, BLEU-2: 0.7584, BLEU-3: 0.7584, BLEU-4: 0.7584
# ROUGE-1: 0.8807, ROUGE-2: 0.8785, ROUGE-L: 0.8807
# CIDEr: 0.0000
#
# Sample 122:
# BLEU-1: 0.3067, BLEU-2: 0.3067, BLEU-3: 0.3067, BLEU-4: 0.3067
# ROUGE-1: 0.6286, ROUGE-2: 0.6061, ROUGE-L: 0.6286
# CIDEr: 0.0000
#
# Sample 123:
# BLEU-1: 0.1146, BLEU-2: 0.1146, BLEU-3: 0.1146, BLEU-4: 0.1146
# ROUGE-1: 0.4348, ROUGE-2: 0.3810, ROUGE-L: 0.4348
# CIDEr: 0.0000
#
# Sample 124:
# BLEU-1: 0.1969, BLEU-2: 0.1969, BLEU-3: 0.1969, BLEU-4: 0.1969
# ROUGE-1: 0.5185, ROUGE-2: 0.4800, ROUGE-L: 0.5185
# CIDEr: 0.0000
#
# Sample 125:
# BLEU-1: 0.3679, BLEU-2: 0.3679, BLEU-3: 0.3679, BLEU-4: 0.3679
# ROUGE-1: 0.6486, ROUGE-2: 0.6286, ROUGE-L: 0.6486
# CIDEr: 0.0000
#
# Sample 126:
# BLEU-1: 0.3951, BLEU-2: 0.3951, BLEU-3: 0.3951, BLEU-4: 0.3951
# ROUGE-1: 0.6829, ROUGE-2: 0.6667, ROUGE-L: 0.6829
# CIDEr: 0.0000
#
# Sample 127:
# BLEU-1: 0.6661, BLEU-2: 0.6661, BLEU-3: 0.6661, BLEU-4: 0.6661
# ROUGE-1: 0.8312, ROUGE-2: 0.8267, ROUGE-L: 0.8312
# CIDEr: 0.0000
#
# Sample 128:
# BLEU-1: 0.6969, BLEU-2: 0.6969, BLEU-3: 0.6969, BLEU-4: 0.6969
# ROUGE-1: 0.8471, ROUGE-2: 0.8434, ROUGE-L: 0.8471
# CIDEr: 0.0000
#
# Sample 129:
# BLEU-1: 0.3951, BLEU-2: 0.3951, BLEU-3: 0.3951, BLEU-4: 0.3951
# ROUGE-1: 0.6977, ROUGE-2: 0.6829, ROUGE-L: 0.6977
# CIDEr: 0.0000
#
# Sample 130:
# BLEU-1: 0.0131, BLEU-2: 0.0131, BLEU-3: 0.0131, BLEU-4: 0.0076
# ROUGE-1: 0.3158, ROUGE-2: 0.2353, ROUGE-L: 0.3158
# CIDEr: 0.0000
#
# Sample 131:
# BLEU-1: 0.0009, BLEU-2: 0.0009, BLEU-3: 0.0009, BLEU-4: 0.0005
# ROUGE-1: 0.2143, ROUGE-2: 0.1538, ROUGE-L: 0.2143
# CIDEr: 0.0000
#
# Sample 132:
# BLEU-1: 0.4857, BLEU-2: 0.4857, BLEU-3: 0.4857, BLEU-4: 0.4857
# ROUGE-1: 0.7347, ROUGE-2: 0.7234, ROUGE-L: 0.7347
# CIDEr: 0.0000
#
# Sample 133:
# BLEU-1: 0.1969, BLEU-2: 0.1969, BLEU-3: 0.1969, BLEU-4: 0.1969
# ROUGE-1: 0.5517, ROUGE-2: 0.5185, ROUGE-L: 0.5517
# CIDEr: 0.0000
#
# Sample 134:
# BLEU-1: 0.7491, BLEU-2: 0.7491, BLEU-3: 0.7491, BLEU-4: 0.7491
# ROUGE-1: 0.8785, ROUGE-2: 0.8762, ROUGE-L: 0.8785
# CIDEr: 0.0000
#
# Sample 135:
# BLEU-1: 0.7103, BLEU-2: 0.7103, BLEU-3: 0.7103, BLEU-4: 0.7103
# ROUGE-1: 0.8539, ROUGE-2: 0.8506, ROUGE-L: 0.8539
# CIDEr: 0.0000
#
# Sample 136:
# BLEU-1: 0.6744, BLEU-2: 0.6744, BLEU-3: 0.6744, BLEU-4: 0.6744
# ROUGE-1: 0.8354, ROUGE-2: 0.8312, ROUGE-L: 0.8354
# CIDEr: 0.0000
#
# Sample 137:
# BLEU-1: 0.3679, BLEU-2: 0.3679, BLEU-3: 0.3679, BLEU-4: 0.3679
# ROUGE-1: 0.6667, ROUGE-2: 0.6486, ROUGE-L: 0.6667
# CIDEr: 0.0000
#
# Sample 138:
# BLEU-1: 0.4857, BLEU-2: 0.4857, BLEU-3: 0.4857, BLEU-4: 0.4857
# ROUGE-1: 0.7347, ROUGE-2: 0.7234, ROUGE-L: 0.7347
# CIDEr: 0.0000
#
# Sample 139:
# BLEU-1: 0.6575, BLEU-2: 0.6575, BLEU-3: 0.6575, BLEU-4: 0.6575
# ROUGE-1: 0.8312, ROUGE-2: 0.8267, ROUGE-L: 0.8312
# CIDEr: 0.0000
#
# Sample 140:
# BLEU-1: 0.0388, BLEU-2: 0.0388, BLEU-3: 0.0388, BLEU-4: 0.0388
# ROUGE-1: 0.3810, ROUGE-2: 0.3158, ROUGE-L: 0.3810
# CIDEr: 0.0000
#
# Sample 141:
# BLEU-1: 0.1561, BLEU-2: 0.1561, BLEU-3: 0.1561, BLEU-4: 0.1561
# ROUGE-1: 0.5517, ROUGE-2: 0.5185, ROUGE-L: 0.5517
# CIDEr: 0.0000
#
# Sample 142:
# BLEU-1: 0.6897, BLEU-2: 0.6897, BLEU-3: 0.6897, BLEU-4: 0.6897
# ROUGE-1: 0.8471, ROUGE-2: 0.8434, ROUGE-L: 0.8471
# CIDEr: 0.0000
#
# Sample 143:
# BLEU-1: 0.5682, BLEU-2: 0.5682, BLEU-3: 0.5682, BLEU-4: 0.5682
# ROUGE-1: 0.7636, ROUGE-2: 0.7547, ROUGE-L: 0.7636
# CIDEr: 0.0000
#
# Sample 144:
# BLEU-1: 0.3679, BLEU-2: 0.3679, BLEU-3: 0.3679, BLEU-4: 0.3679
# ROUGE-1: 0.6829, ROUGE-2: 0.6667, ROUGE-L: 0.6829
# CIDEr: 0.0000
#
# Sample 145:
# BLEU-1: 0.6483, BLEU-2: 0.6483, BLEU-3: 0.6483, BLEU-4: 0.6483
# ROUGE-1: 0.8267, ROUGE-2: 0.8219, ROUGE-L: 0.8267
# CIDEr: 0.0000
#
# Sample 146:
# BLEU-1: 0.6286, BLEU-2: 0.6286, BLEU-3: 0.6286, BLEU-4: 0.6286
# ROUGE-1: 0.8000, ROUGE-2: 0.7937, ROUGE-L: 0.8000
# CIDEr: 0.0000
#
# Sample 147:
# BLEU-1: 0.5045, BLEU-2: 0.5045, BLEU-3: 0.5045, BLEU-4: 0.5045
# ROUGE-1: 0.7451, ROUGE-2: 0.7347, ROUGE-L: 0.7451
# CIDEr: 0.0000
#
# Sample 148:
# BLEU-1: 0.3067, BLEU-2: 0.3067, BLEU-3: 0.3067, BLEU-4: 0.3067
# ROUGE-1: 0.5806, ROUGE-2: 0.5517, ROUGE-L: 0.5806
# CIDEr: 0.0000
#
# Sample 149:
# BLEU-1: 0.5045, BLEU-2: 0.5045, BLEU-3: 0.5045, BLEU-4: 0.5045
# ROUGE-1: 0.7451, ROUGE-2: 0.7347, ROUGE-L: 0.7451
# CIDEr: 0.0000
#
# Sample 150:
# BLEU-1: 0.6823, BLEU-2: 0.6823, BLEU-3: 0.6823, BLEU-4: 0.6823
# ROUGE-1: 0.8395, ROUGE-2: 0.8354, ROUGE-L: 0.8395
# CIDEr: 0.0000
#
# Sample 151:
# BLEU-1: 0.6575, BLEU-2: 0.6575, BLEU-3: 0.6575, BLEU-4: 0.6575
# ROUGE-1: 0.8267, ROUGE-2: 0.8219, ROUGE-L: 0.8267
# CIDEr: 0.0000
#
# Sample 152:
# BLEU-1: 0.3679, BLEU-2: 0.3679, BLEU-3: 0.3679, BLEU-4: 0.3679
# ROUGE-1: 0.6667, ROUGE-2: 0.6486, ROUGE-L: 0.6667
# CIDEr: 0.0000
#
# Sample 153:
# BLEU-1: 0.4655, BLEU-2: 0.4655, BLEU-3: 0.4655, BLEU-4: 0.4655
# ROUGE-1: 0.7347, ROUGE-2: 0.7234, ROUGE-L: 0.7347
# CIDEr: 0.0000
#
# Sample 154:
# BLEU-1: 0.6065, BLEU-2: 0.6065, BLEU-3: 0.6065, BLEU-4: 0.6065
# ROUGE-1: 0.8060, ROUGE-2: 0.8000, ROUGE-L: 0.8060
# CIDEr: 0.0000
#
# Sample 155:
# BLEU-1: 0.7491, BLEU-2: 0.7491, BLEU-3: 0.7491, BLEU-4: 0.7491
# ROUGE-1: 0.8738, ROUGE-2: 0.8713, ROUGE-L: 0.8738
# CIDEr: 0.0000
#
# Sample 156:
# BLEU-1: 0.5538, BLEU-2: 0.5538, BLEU-3: 0.5538, BLEU-4: 0.5538
# ROUGE-1: 0.7719, ROUGE-2: 0.7636, ROUGE-L: 0.7719
# CIDEr: 0.0000
#
# Sample 157:
# BLEU-1: 0.5682, BLEU-2: 0.5682, BLEU-3: 0.5682, BLEU-4: 0.5682
# ROUGE-1: 0.7719, ROUGE-2: 0.7636, ROUGE-L: 0.7719
# CIDEr: 0.0000
#
# Sample 158:
# BLEU-1: 0.7037, BLEU-2: 0.7037, BLEU-3: 0.7037, BLEU-4: 0.7037
# ROUGE-1: 0.8539, ROUGE-2: 0.8506, ROUGE-L: 0.8539
# CIDEr: 0.0000
#
# Sample 159:
# BLEU-1: 0.4437, BLEU-2: 0.4437, BLEU-3: 0.4437, BLEU-4: 0.4437
# ROUGE-1: 0.7234, ROUGE-2: 0.7111, ROUGE-L: 0.7234
# CIDEr: 0.0000
#
# Sample 160:
# BLEU-1: 0.1969, BLEU-2: 0.1969, BLEU-3: 0.1969, BLEU-4: 0.1969
# ROUGE-1: 0.5185, ROUGE-2: 0.4800, ROUGE-L: 0.5185
# CIDEr: 0.0000
#
# Sample 161:
# BLEU-1: 0.6575, BLEU-2: 0.6575, BLEU-3: 0.6575, BLEU-4: 0.6575
# ROUGE-1: 0.8312, ROUGE-2: 0.8267, ROUGE-L: 0.8312
# CIDEr: 0.0000
#
# Sample 162:
# BLEU-1: 0.4204, BLEU-2: 0.4204, BLEU-3: 0.4204, BLEU-4: 0.4204
# ROUGE-1: 0.7111, ROUGE-2: 0.6977, ROUGE-L: 0.7111
# CIDEr: 0.0000
#
# Sample 163:
# BLEU-1: 0.3679, BLEU-2: 0.3679, BLEU-3: 0.3679, BLEU-4: 0.3679
# ROUGE-1: 0.6667, ROUGE-2: 0.6486, ROUGE-L: 0.6667
# CIDEr: 0.0000
#
# Sample 164:
# BLEU-1: 0.7750, BLEU-2: 0.7750, BLEU-3: 0.7750, BLEU-4: 0.7750
# ROUGE-1: 0.8850, ROUGE-2: 0.8829, ROUGE-L: 0.8850
# CIDEr: 0.0000
#
# Sample 165:
# BLEU-1: 0.6897, BLEU-2: 0.6897, BLEU-3: 0.6897, BLEU-4: 0.6897
# ROUGE-1: 0.8571, ROUGE-2: 0.8539, ROUGE-L: 0.8571
# CIDEr: 0.0000
#
# Sample 166:
# BLEU-1: 0.3951, BLEU-2: 0.3951, BLEU-3: 0.3951, BLEU-4: 0.3951
# ROUGE-1: 0.7111, ROUGE-2: 0.6977, ROUGE-L: 0.7111
# CIDEr: 0.0000
#
# Sample 167:
# BLEU-1: 0.6483, BLEU-2: 0.6483, BLEU-3: 0.6483, BLEU-4: 0.6483
# ROUGE-1: 0.8267, ROUGE-2: 0.8219, ROUGE-L: 0.8267
# CIDEr: 0.0000
#
# Sample 168:
# BLEU-1: 0.3067, BLEU-2: 0.3067, BLEU-3: 0.3067, BLEU-4: 0.3067
# ROUGE-1: 0.6286, ROUGE-2: 0.6061, ROUGE-L: 0.6286
# CIDEr: 0.0000
#
# Sample 169:
# BLEU-1: 0.7442, BLEU-2: 0.7442, BLEU-3: 0.7442, BLEU-4: 0.7442
# ROUGE-1: 0.8738, ROUGE-2: 0.8713, ROUGE-L: 0.8738
# CIDEr: 0.0000
#
# Sample 170:
# BLEU-1: 0.3385, BLEU-2: 0.3385, BLEU-3: 0.3385, BLEU-4: 0.3385
# ROUGE-1: 0.6486, ROUGE-2: 0.6286, ROUGE-L: 0.6486
# CIDEr: 0.0000
#
# Sample 171:
# BLEU-1: 0.7338, BLEU-2: 0.7338, BLEU-3: 0.7338, BLEU-4: 0.7338
# ROUGE-1: 0.8632, ROUGE-2: 0.8602, ROUGE-L: 0.8632
# CIDEr: 0.0000
#
# Sample 172:
# BLEU-1: 0.3385, BLEU-2: 0.3385, BLEU-3: 0.3385, BLEU-4: 0.3385
# ROUGE-1: 0.6486, ROUGE-2: 0.6286, ROUGE-L: 0.6486
# CIDEr: 0.0000
#
# Sample 173:
# BLEU-1: 0.6661, BLEU-2: 0.6661, BLEU-3: 0.6661, BLEU-4: 0.6661
# ROUGE-1: 0.8312, ROUGE-2: 0.8267, ROUGE-L: 0.8312
# CIDEr: 0.0000
#
# Sample 174:
# BLEU-1: 0.7391, BLEU-2: 0.7391, BLEU-3: 0.7391, BLEU-4: 0.7391
# ROUGE-1: 0.8687, ROUGE-2: 0.8660, ROUGE-L: 0.8687
# CIDEr: 0.0000
#
# Sample 175:
# BLEU-1: 0.7037, BLEU-2: 0.7037, BLEU-3: 0.7037, BLEU-4: 0.7037
# ROUGE-1: 0.8539, ROUGE-2: 0.8506, ROUGE-L: 0.8539
# CIDEr: 0.0000
#
# Sample 176:
# BLEU-1: 0.3067, BLEU-2: 0.3067, BLEU-3: 0.3067, BLEU-4: 0.3067
# ROUGE-1: 0.6667, ROUGE-2: 0.6486, ROUGE-L: 0.6667
# CIDEr: 0.0000
#
# Sample 177:
# BLEU-1: 0.5385, BLEU-2: 0.5385, BLEU-3: 0.5385, BLEU-4: 0.5385
# ROUGE-1: 0.7636, ROUGE-2: 0.7547, ROUGE-L: 0.7636
# CIDEr: 0.0000
#
# Sample 178:
# BLEU-1: 0.5220, BLEU-2: 0.5220, BLEU-3: 0.5220, BLEU-4: 0.5220
# ROUGE-1: 0.7636, ROUGE-2: 0.7547, ROUGE-L: 0.7636
# CIDEr: 0.0000
#
# Sample 179:
# BLEU-1: 0.6065, BLEU-2: 0.6065, BLEU-3: 0.6065, BLEU-4: 0.6065
# ROUGE-1: 0.8000, ROUGE-2: 0.7937, ROUGE-L: 0.8000
# CIDEr: 0.0000
#
# Sample 180:
# BLEU-1: 0.5682, BLEU-2: 0.5682, BLEU-3: 0.5682, BLEU-4: 0.5682
# ROUGE-1: 0.7797, ROUGE-2: 0.7719, ROUGE-L: 0.7797
# CIDEr: 0.0000
#
# Sample 181:
# BLEU-1: 0.3067, BLEU-2: 0.3067, BLEU-3: 0.3067, BLEU-4: 0.3067
# ROUGE-1: 0.6286, ROUGE-2: 0.6061, ROUGE-L: 0.6286
# CIDEr: 0.0000
#
# Sample 182:
# BLEU-1: 0.3067, BLEU-2: 0.3067, BLEU-3: 0.3067, BLEU-4: 0.3067
# ROUGE-1: 0.6486, ROUGE-2: 0.6286, ROUGE-L: 0.6486
# CIDEr: 0.0000
#
# Sample 183:
# BLEU-1: 0.1969, BLEU-2: 0.1969, BLEU-3: 0.1969, BLEU-4: 0.1969
# ROUGE-1: 0.5517, ROUGE-2: 0.5185, ROUGE-L: 0.5517
# CIDEr: 0.0000
#
# Sample 184:
# BLEU-1: 0.1146, BLEU-2: 0.1146, BLEU-3: 0.1146, BLEU-4: 0.1146
# ROUGE-1: 0.4800, ROUGE-2: 0.4348, ROUGE-L: 0.4800
# CIDEr: 0.0000
#
# Sample 185:
# BLEU-1: 0.6483, BLEU-2: 0.6483, BLEU-3: 0.6483, BLEU-4: 0.6483
# ROUGE-1: 0.8219, ROUGE-2: 0.8169, ROUGE-L: 0.8219
# CIDEr: 0.0000
#
# Sample 186:
# BLEU-1: 0.4204, BLEU-2: 0.4204, BLEU-3: 0.4204, BLEU-4: 0.4204
# ROUGE-1: 0.6977, ROUGE-2: 0.6829, ROUGE-L: 0.6977
# CIDEr: 0.0000
#
# Sample 187:
# BLEU-1: 0.5682, BLEU-2: 0.5682, BLEU-3: 0.5682, BLEU-4: 0.5682
# ROUGE-1: 0.7869, ROUGE-2: 0.7797, ROUGE-L: 0.7869
# CIDEr: 0.0000
#
# Sample 188:
# BLEU-1: 0.4204, BLEU-2: 0.4204, BLEU-3: 0.4204, BLEU-4: 0.4204
# ROUGE-1: 0.6977, ROUGE-2: 0.6829, ROUGE-L: 0.6977
# CIDEr: 0.0000
#
# Sample 189:
# BLEU-1: 0.6286, BLEU-2: 0.6286, BLEU-3: 0.6286, BLEU-4: 0.6286
# ROUGE-1: 0.8169, ROUGE-2: 0.8116, ROUGE-L: 0.8169
# CIDEr: 0.0000
#
# Sample 190:
# BLEU-1: 0.2359, BLEU-2: 0.2359, BLEU-3: 0.2359, BLEU-4: 0.2359
# ROUGE-1: 0.5806, ROUGE-2: 0.5517, ROUGE-L: 0.5806
# CIDEr: 0.0000
#
# Sample 191:
# BLEU-1: 0.3385, BLEU-2: 0.3385, BLEU-3: 0.3385, BLEU-4: 0.3385
# ROUGE-1: 0.6486, ROUGE-2: 0.6286, ROUGE-L: 0.6486
# CIDEr: 0.0000
#
# Sample 192:
# BLEU-1: 0.5818, BLEU-2: 0.5818, BLEU-3: 0.5818, BLEU-4: 0.5818
# ROUGE-1: 0.7869, ROUGE-2: 0.7797, ROUGE-L: 0.7869
# CIDEr: 0.0000
#
# Sample 193:
# BLEU-1: 0.7584, BLEU-2: 0.7584, BLEU-3: 0.7584, BLEU-4: 0.7584
# ROUGE-1: 0.8785, ROUGE-2: 0.8762, ROUGE-L: 0.8785
# CIDEr: 0.0000
#
# Sample 194:
# BLEU-1: 0.6823, BLEU-2: 0.6823, BLEU-3: 0.6823, BLEU-4: 0.6823
# ROUGE-1: 0.8434, ROUGE-2: 0.8395, ROUGE-L: 0.8434
# CIDEr: 0.0000
#
# Sample 195:
# BLEU-1: 0.4655, BLEU-2: 0.4655, BLEU-3: 0.4655, BLEU-4: 0.4655
# ROUGE-1: 0.7547, ROUGE-2: 0.7451, ROUGE-L: 0.7547
# CIDEr: 0.0000
#
# Sample 196:
# BLEU-1: 0.3385, BLEU-2: 0.3385, BLEU-3: 0.3385, BLEU-4: 0.3385
# ROUGE-1: 0.6486, ROUGE-2: 0.6286, ROUGE-L: 0.6486
# CIDEr: 0.0000
#
# Sample 197:
# BLEU-1: 0.7538, BLEU-2: 0.7538, BLEU-3: 0.7538, BLEU-4: 0.7538
# ROUGE-1: 0.8785, ROUGE-2: 0.8762, ROUGE-L: 0.8785
# CIDEr: 0.0000
#
# Sample 198:
# BLEU-1: 0.3679, BLEU-2: 0.3679, BLEU-3: 0.3679, BLEU-4: 0.3679
# ROUGE-1: 0.6667, ROUGE-2: 0.6486, ROUGE-L: 0.6667
# CIDEr: 0.0000
#
# Sample 199:
# BLEU-1: 0.5220, BLEU-2: 0.5220, BLEU-3: 0.5220, BLEU-4: 0.5220
# ROUGE-1: 0.7636, ROUGE-2: 0.7547, ROUGE-L: 0.7636
# CIDEr: 0.0000
#
# Sample 200:
# BLEU-1: 0.3385, BLEU-2: 0.3385, BLEU-3: 0.3385, BLEU-4: 0.3385
# ROUGE-1: 0.6667, ROUGE-2: 0.6486, ROUGE-L: 0.6667
# CIDEr: 0.0000
#
# Sample 201:
# BLEU-1: 0.3385, BLEU-2: 0.3385, BLEU-3: 0.3385, BLEU-4: 0.3385
# ROUGE-1: 0.6667, ROUGE-2: 0.6486, ROUGE-L: 0.6667
# CIDEr: 0.0000
#
# Sample 202:
# BLEU-1: 0.2725, BLEU-2: 0.2725, BLEU-3: 0.2725, BLEU-4: 0.2725
# ROUGE-1: 0.6061, ROUGE-2: 0.5806, ROUGE-L: 0.6061
# CIDEr: 0.0000
#
# Sample 203:
# BLEU-1: 0.6387, BLEU-2: 0.6387, BLEU-3: 0.6387, BLEU-4: 0.6387
# ROUGE-1: 0.8169, ROUGE-2: 0.8116, ROUGE-L: 0.8169
# CIDEr: 0.0000
#
# Sample 204:
# BLEU-1: 0.4857, BLEU-2: 0.4857, BLEU-3: 0.4857, BLEU-4: 0.4857
# ROUGE-1: 0.7234, ROUGE-2: 0.7111, ROUGE-L: 0.7234
# CIDEr: 0.0000
#
# Sample 205:
# BLEU-1: 0.4857, BLEU-2: 0.4857, BLEU-3: 0.4857, BLEU-4: 0.4857
# ROUGE-1: 0.7347, ROUGE-2: 0.7234, ROUGE-L: 0.7347
# CIDEr: 0.0000
#
# Sample 206:
# BLEU-1: 0.2359, BLEU-2: 0.2359, BLEU-3: 0.2359, BLEU-4: 0.2359
# ROUGE-1: 0.5806, ROUGE-2: 0.5517, ROUGE-L: 0.5806
# CIDEr: 0.0000
#
# Sample 207:
# BLEU-1: 0.6575, BLEU-2: 0.6575, BLEU-3: 0.6575, BLEU-4: 0.6575
# ROUGE-1: 0.8312, ROUGE-2: 0.8267, ROUGE-L: 0.8312
# CIDEr: 0.0000
#
# Sample 208:
# BLEU-1: 0.7391, BLEU-2: 0.7391, BLEU-3: 0.7391, BLEU-4: 0.7391
# ROUGE-1: 0.8687, ROUGE-2: 0.8660, ROUGE-L: 0.8687
# CIDEr: 0.0000
#
# Sample 209:
# BLEU-1: 0.6483, BLEU-2: 0.6483, BLEU-3: 0.6483, BLEU-4: 0.6483
# ROUGE-1: 0.8219, ROUGE-2: 0.8169, ROUGE-L: 0.8219
# CIDEr: 0.0000
#
# Sample 210:
# BLEU-1: 0.5220, BLEU-2: 0.5220, BLEU-3: 0.5220, BLEU-4: 0.5220
# ROUGE-1: 0.7719, ROUGE-2: 0.7636, ROUGE-L: 0.7719
# CIDEr: 0.0000
#
# Sample 211:
# BLEU-1: 0.3067, BLEU-2: 0.3067, BLEU-3: 0.3067, BLEU-4: 0.3067
# ROUGE-1: 0.6486, ROUGE-2: 0.6286, ROUGE-L: 0.6486
# CIDEr: 0.0000
#
# Sample 212:
# BLEU-1: 0.7338, BLEU-2: 0.7338, BLEU-3: 0.7338, BLEU-4: 0.7338
# ROUGE-1: 0.8660, ROUGE-2: 0.8632, ROUGE-L: 0.8660
# CIDEr: 0.0000
#
# Sample 213:
# BLEU-1: 0.6286, BLEU-2: 0.6286, BLEU-3: 0.6286, BLEU-4: 0.6286
# ROUGE-1: 0.8116, ROUGE-2: 0.8060, ROUGE-L: 0.8116
# CIDEr: 0.0000
#
# Sample 214:
# BLEU-1: 0.5220, BLEU-2: 0.5220, BLEU-3: 0.5220, BLEU-4: 0.5220
# ROUGE-1: 0.7547, ROUGE-2: 0.7451, ROUGE-L: 0.7547
# CIDEr: 0.0000
#
# Sample 215:
# BLEU-1: 0.6823, BLEU-2: 0.6823, BLEU-3: 0.6823, BLEU-4: 0.6823
# ROUGE-1: 0.8395, ROUGE-2: 0.8354, ROUGE-L: 0.8395
# CIDEr: 0.0000
#
# Sample 216:
# BLEU-1: 0.2359, BLEU-2: 0.2359, BLEU-3: 0.2359, BLEU-4: 0.2359
# ROUGE-1: 0.5806, ROUGE-2: 0.5517, ROUGE-L: 0.5806
# CIDEr: 0.0000
#
# Sample 217:
# BLEU-1: 0.2725, BLEU-2: 0.2725, BLEU-3: 0.2725, BLEU-4: 0.2725
# ROUGE-1: 0.6061, ROUGE-2: 0.5806, ROUGE-L: 0.6061
# CIDEr: 0.0000
#
# Sample 218:
# BLEU-1: 0.3385, BLEU-2: 0.3385, BLEU-3: 0.3385, BLEU-4: 0.3385
# ROUGE-1: 0.6829, ROUGE-2: 0.6667, ROUGE-L: 0.6829
# CIDEr: 0.0000
#
# Sample 219:
# BLEU-1: 0.5682, BLEU-2: 0.5682, BLEU-3: 0.5682, BLEU-4: 0.5682
# ROUGE-1: 0.7797, ROUGE-2: 0.7719, ROUGE-L: 0.7797
# CIDEr: 0.0000
#
# Sample 220:
# BLEU-1: 0.6387, BLEU-2: 0.6387, BLEU-3: 0.6387, BLEU-4: 0.6387
# ROUGE-1: 0.8169, ROUGE-2: 0.8116, ROUGE-L: 0.8169
# CIDEr: 0.0000
#
# Sample 221:
# BLEU-1: 0.4437, BLEU-2: 0.4437, BLEU-3: 0.4437, BLEU-4: 0.4437
# ROUGE-1: 0.7111, ROUGE-2: 0.6977, ROUGE-L: 0.7111
# CIDEr: 0.0000
#
# Sample 222:
# BLEU-1: 0.0743, BLEU-2: 0.0743, BLEU-3: 0.0743, BLEU-4: 0.0743
# ROUGE-1: 0.4348, ROUGE-2: 0.3810, ROUGE-L: 0.4348
# CIDEr: 0.0000
#
# Sample 223:
# BLEU-1: 0.6387, BLEU-2: 0.6387, BLEU-3: 0.6387, BLEU-4: 0.6387
# ROUGE-1: 0.8219, ROUGE-2: 0.8169, ROUGE-L: 0.8219
# CIDEr: 0.0000
#
# Sample 224:
# BLEU-1: 0.7338, BLEU-2: 0.7338, BLEU-3: 0.7338, BLEU-4: 0.7338
# ROUGE-1: 0.8660, ROUGE-2: 0.8632, ROUGE-L: 0.8660
# CIDEr: 0.0000
#
# Sample 225:
# BLEU-1: 0.3067, BLEU-2: 0.3067, BLEU-3: 0.3067, BLEU-4: 0.3067
# ROUGE-1: 0.6286, ROUGE-2: 0.6061, ROUGE-L: 0.6286
# CIDEr: 0.0000
#
# Sample 226:
# BLEU-1: 0.4204, BLEU-2: 0.4204, BLEU-3: 0.4204, BLEU-4: 0.4204
# ROUGE-1: 0.7111, ROUGE-2: 0.6977, ROUGE-L: 0.7111
# CIDEr: 0.0000
#
# Sample 227:
# BLEU-1: 0.3385, BLEU-2: 0.3385, BLEU-3: 0.3385, BLEU-4: 0.3385
# ROUGE-1: 0.6667, ROUGE-2: 0.6486, ROUGE-L: 0.6667
# CIDEr: 0.0000
#
# Sample 228:
# BLEU-1: 0.0131, BLEU-2: 0.0131, BLEU-3: 0.0131, BLEU-4: 0.0076
# ROUGE-1: 0.3158, ROUGE-2: 0.2353, ROUGE-L: 0.3158
# CIDEr: 0.0000
#
# Sample 229:
# BLEU-1: 0.3220, BLEU-2: 0.3220, BLEU-3: 0.3220, BLEU-4: 0.3220
# ROUGE-1: 0.6383, ROUGE-2: 0.6222, ROUGE-L: 0.6383
# CIDEr: 0.0000
#
# Sample 230:
# BLEU-1: 0.4857, BLEU-2: 0.4857, BLEU-3: 0.4857, BLEU-4: 0.4857
# ROUGE-1: 0.7111, ROUGE-2: 0.6977, ROUGE-L: 0.7111
# CIDEr: 0.0000
#
# Sample 231:
# BLEU-1: 0.7037, BLEU-2: 0.7037, BLEU-3: 0.7037, BLEU-4: 0.7037
# ROUGE-1: 0.8506, ROUGE-2: 0.8471, ROUGE-L: 0.8506
# CIDEr: 0.0000
#
# Sample 232:
# BLEU-1: 0.2725, BLEU-2: 0.2725, BLEU-3: 0.2725, BLEU-4: 0.2725
# ROUGE-1: 0.6061, ROUGE-2: 0.5806, ROUGE-L: 0.6061
# CIDEr: 0.0000
#
# Sample 233:
# BLEU-1: 0.5682, BLEU-2: 0.5682, BLEU-3: 0.5682, BLEU-4: 0.5682
# ROUGE-1: 0.7869, ROUGE-2: 0.7797, ROUGE-L: 0.7869
# CIDEr: 0.0000
#
# Sample 234:
# BLEU-1: 0.6823, BLEU-2: 0.6823, BLEU-3: 0.6823, BLEU-4: 0.6823
# ROUGE-1: 0.8354, ROUGE-2: 0.8312, ROUGE-L: 0.8354
# CIDEr: 0.0000
#
# Sample 235:
# BLEU-1: 0.3067, BLEU-2: 0.3067, BLEU-3: 0.3067, BLEU-4: 0.3067
# ROUGE-1: 0.6286, ROUGE-2: 0.6061, ROUGE-L: 0.6286
# CIDEr: 0.0000
#
# Sample 236:
# BLEU-1: 0.7442, BLEU-2: 0.7442, BLEU-3: 0.7442, BLEU-4: 0.7442
# ROUGE-1: 0.8785, ROUGE-2: 0.8762, ROUGE-L: 0.8785
# CIDEr: 0.0000
#
# Sample 237:
# BLEU-1: 0.2359, BLEU-2: 0.2359, BLEU-3: 0.2359, BLEU-4: 0.2359
# ROUGE-1: 0.6061, ROUGE-2: 0.5806, ROUGE-L: 0.6061
# CIDEr: 0.0000
#
# Sample 238:
# BLEU-1: 0.1561, BLEU-2: 0.1561, BLEU-3: 0.1561, BLEU-4: 0.1561
# ROUGE-1: 0.5185, ROUGE-2: 0.4800, ROUGE-L: 0.5185
# CIDEr: 0.0000
#
# Sample 239:
# BLEU-1: 0.2359, BLEU-2: 0.2359, BLEU-3: 0.2359, BLEU-4: 0.2359
# ROUGE-1: 0.4800, ROUGE-2: 0.4348, ROUGE-L: 0.4800
# CIDEr: 0.0000
#
# Sample 240:
# BLEU-1: 0.7491, BLEU-2: 0.7491, BLEU-3: 0.7491, BLEU-4: 0.7491
# ROUGE-1: 0.8738, ROUGE-2: 0.8713, ROUGE-L: 0.8738
# CIDEr: 0.0000
#
# Sample 241:
# BLEU-1: 0.0388, BLEU-2: 0.0388, BLEU-3: 0.0388, BLEU-4: 0.0388
# ROUGE-1: 0.3810, ROUGE-2: 0.3158, ROUGE-L: 0.3810
# CIDEr: 0.0000
#
# Sample 242:
# BLEU-1: 0.5220, BLEU-2: 0.5220, BLEU-3: 0.5220, BLEU-4: 0.5220
# ROUGE-1: 0.7547, ROUGE-2: 0.7451, ROUGE-L: 0.7547
# CIDEr: 0.0000
#
# Sample 243:
# BLEU-1: 0.2725, BLEU-2: 0.2725, BLEU-3: 0.2725, BLEU-4: 0.2725
# ROUGE-1: 0.6061, ROUGE-2: 0.5806, ROUGE-L: 0.6061
# CIDEr: 0.0000
#
# Sample 244:
# BLEU-1: 0.3951, BLEU-2: 0.3951, BLEU-3: 0.3951, BLEU-4: 0.3951
# ROUGE-1: 0.7234, ROUGE-2: 0.7111, ROUGE-L: 0.7234
# CIDEr: 0.0000
#
# Sample 245:
# BLEU-1: 0.6065, BLEU-2: 0.6065, BLEU-3: 0.6065, BLEU-4: 0.6065
# ROUGE-1: 0.8000, ROUGE-2: 0.7937, ROUGE-L: 0.8000
# CIDEr: 0.0000
#
# Sample 246:
# BLEU-1: 0.5045, BLEU-2: 0.5045, BLEU-3: 0.5045, BLEU-4: 0.5045
# ROUGE-1: 0.7547, ROUGE-2: 0.7451, ROUGE-L: 0.7547
# CIDEr: 0.0000
#
# Sample 247:
# BLEU-1: 0.7037, BLEU-2: 0.7037, BLEU-3: 0.7037, BLEU-4: 0.7037
# ROUGE-1: 0.8571, ROUGE-2: 0.8539, ROUGE-L: 0.8571
# CIDEr: 0.0000
#
# Sample 248:
# BLEU-1: 0.6897, BLEU-2: 0.6897, BLEU-3: 0.6897, BLEU-4: 0.6897
# ROUGE-1: 0.8434, ROUGE-2: 0.8395, ROUGE-L: 0.8434
# CIDEr: 0.0000
#
# Sample 249:
# BLEU-1: 0.4204, BLEU-2: 0.4204, BLEU-3: 0.4204, BLEU-4: 0.4204
# ROUGE-1: 0.6977, ROUGE-2: 0.6829, ROUGE-L: 0.6977
# CIDEr: 0.0000
#
# Sample 250:
# BLEU-1: 0.3385, BLEU-2: 0.3385, BLEU-3: 0.3385, BLEU-4: 0.3385
# ROUGE-1: 0.6667, ROUGE-2: 0.6486, ROUGE-L: 0.6667
# CIDEr: 0.0000
#
# Sample 251:
# BLEU-1: 0.7037, BLEU-2: 0.7037, BLEU-3: 0.7037, BLEU-4: 0.7037
# ROUGE-1: 0.8539, ROUGE-2: 0.8506, ROUGE-L: 0.8539
# CIDEr: 0.0000
#
# Sample 252:
# BLEU-1: 0.5682, BLEU-2: 0.5682, BLEU-3: 0.5682, BLEU-4: 0.5682
# ROUGE-1: 0.7869, ROUGE-2: 0.7797, ROUGE-L: 0.7869
# CIDEr: 0.0000
#
# Sample 253:
# BLEU-1: 0.7165, BLEU-2: 0.7165, BLEU-3: 0.7165, BLEU-4: 0.7165
# ROUGE-1: 0.8506, ROUGE-2: 0.8471, ROUGE-L: 0.8506
# CIDEr: 0.0000
#
# Sample 254:
# BLEU-1: 0.5818, BLEU-2: 0.5818, BLEU-3: 0.5818, BLEU-4: 0.5818
# ROUGE-1: 0.7937, ROUGE-2: 0.7869, ROUGE-L: 0.7937
# CIDEr: 0.0000
#
# Sample 255:
# BLEU-1: 0.6744, BLEU-2: 0.6744, BLEU-3: 0.6744, BLEU-4: 0.6744
# ROUGE-1: 0.8395, ROUGE-2: 0.8354, ROUGE-L: 0.8395
# CIDEr: 0.0000
#
# Sample 256:
# BLEU-1: 0.7825, BLEU-2: 0.7825, BLEU-3: 0.7825, BLEU-4: 0.7825
# ROUGE-1: 0.8960, ROUGE-2: 0.8943, ROUGE-L: 0.8960
# CIDEr: 0.0000
#
# Sample 257:
# BLEU-1: 0.6065, BLEU-2: 0.6065, BLEU-3: 0.6065, BLEU-4: 0.6065
# ROUGE-1: 0.8000, ROUGE-2: 0.7937, ROUGE-L: 0.8000
# CIDEr: 0.0000
#
# Sample 258:
# BLEU-1: 0.4655, BLEU-2: 0.4655, BLEU-3: 0.4655, BLEU-4: 0.4655
# ROUGE-1: 0.7234, ROUGE-2: 0.7111, ROUGE-L: 0.7234
# CIDEr: 0.0000
#
# Sample 259:
# BLEU-1: 0.5538, BLEU-2: 0.5538, BLEU-3: 0.5538, BLEU-4: 0.5538
# ROUGE-1: 0.7719, ROUGE-2: 0.7636, ROUGE-L: 0.7719
# CIDEr: 0.0000
#
# Sample 260:
# BLEU-1: 0.4437, BLEU-2: 0.4437, BLEU-3: 0.4437, BLEU-4: 0.4437
# ROUGE-1: 0.7111, ROUGE-2: 0.6977, ROUGE-L: 0.7111
# CIDEr: 0.0000
#
# Sample 261:
# BLEU-1: 0.1969, BLEU-2: 0.1969, BLEU-3: 0.1969, BLEU-4: 0.1969
# ROUGE-1: 0.5517, ROUGE-2: 0.5185, ROUGE-L: 0.5517
# CIDEr: 0.0000
#
# Sample 262:
# BLEU-1: 0.5220, BLEU-2: 0.5220, BLEU-3: 0.5220, BLEU-4: 0.5220
# ROUGE-1: 0.7719, ROUGE-2: 0.7636, ROUGE-L: 0.7719
# CIDEr: 0.0000
#
# Sample 263:
# BLEU-1: 0.6575, BLEU-2: 0.6575, BLEU-3: 0.6575, BLEU-4: 0.6575
# ROUGE-1: 0.8395, ROUGE-2: 0.8354, ROUGE-L: 0.8395
# CIDEr: 0.0000
#
# Sample 264:
# BLEU-1: 0.0131, BLEU-2: 0.0131, BLEU-3: 0.0131, BLEU-4: 0.0076
# ROUGE-1: 0.3158, ROUGE-2: 0.2353, ROUGE-L: 0.3158
# CIDEr: 0.0000
#
# Sample 265:
# BLEU-1: 0.2359, BLEU-2: 0.2359, BLEU-3: 0.2359, BLEU-4: 0.2359
# ROUGE-1: 0.5806, ROUGE-2: 0.5517, ROUGE-L: 0.5806
# CIDEr: 0.0000
#
# Sample 266:
# BLEU-1: 0.6823, BLEU-2: 0.6823, BLEU-3: 0.6823, BLEU-4: 0.6823
# ROUGE-1: 0.8354, ROUGE-2: 0.8312, ROUGE-L: 0.8354
# CIDEr: 0.0000
#
# Sample 267:
# BLEU-1: 0.6286, BLEU-2: 0.6286, BLEU-3: 0.6286, BLEU-4: 0.6286
# ROUGE-1: 0.8169, ROUGE-2: 0.8116, ROUGE-L: 0.8169
# CIDEr: 0.0000
#
# Sample 268:
# BLEU-1: 0.6969, BLEU-2: 0.6969, BLEU-3: 0.6969, BLEU-4: 0.6969
# ROUGE-1: 0.8506, ROUGE-2: 0.8471, ROUGE-L: 0.8506
# CIDEr: 0.0000
#
# Sample 269:
# BLEU-1: 0.3067, BLEU-2: 0.3067, BLEU-3: 0.3067, BLEU-4: 0.3067
# ROUGE-1: 0.6486, ROUGE-2: 0.6286, ROUGE-L: 0.6486
# CIDEr: 0.0000
#
# Sample 270:
# BLEU-1: 0.7391, BLEU-2: 0.7391, BLEU-3: 0.7391, BLEU-4: 0.7391
# ROUGE-1: 0.8738, ROUGE-2: 0.8713, ROUGE-L: 0.8738
# CIDEr: 0.0000
#
# Sample 271:
# BLEU-1: 0.7391, BLEU-2: 0.7391, BLEU-3: 0.7391, BLEU-4: 0.7391
# ROUGE-1: 0.8660, ROUGE-2: 0.8632, ROUGE-L: 0.8660
# CIDEr: 0.0000
#
# Sample 272:
# BLEU-1: 0.3679, BLEU-2: 0.3679, BLEU-3: 0.3679, BLEU-4: 0.3679
# ROUGE-1: 0.6667, ROUGE-2: 0.6486, ROUGE-L: 0.6667
# CIDEr: 0.0000
#
# Sample 273:
# BLEU-1: 0.5682, BLEU-2: 0.5682, BLEU-3: 0.5682, BLEU-4: 0.5682
# ROUGE-1: 0.7797, ROUGE-2: 0.7719, ROUGE-L: 0.7797
# CIDEr: 0.0000
#
# Sample 274:
# BLEU-1: 0.2725, BLEU-2: 0.2725, BLEU-3: 0.2725, BLEU-4: 0.2725
# ROUGE-1: 0.6061, ROUGE-2: 0.5806, ROUGE-L: 0.6061
# CIDEr: 0.0000
#
# Sample 275:
# BLEU-1: 0.5220, BLEU-2: 0.5220, BLEU-3: 0.5220, BLEU-4: 0.5220
# ROUGE-1: 0.7451, ROUGE-2: 0.7347, ROUGE-L: 0.7451
# CIDEr: 0.0000
#
# Sample 276:
# BLEU-1: 0.6179, BLEU-2: 0.6179, BLEU-3: 0.6179, BLEU-4: 0.6179
# ROUGE-1: 0.8060, ROUGE-2: 0.8000, ROUGE-L: 0.8060
# CIDEr: 0.0000
#
# Sample 277:
# BLEU-1: 0.7225, BLEU-2: 0.7225, BLEU-3: 0.7225, BLEU-4: 0.7225
# ROUGE-1: 0.8660, ROUGE-2: 0.8632, ROUGE-L: 0.8660
# CIDEr: 0.0000
#
# Sample 278:
# BLEU-1: 0.5220, BLEU-2: 0.5220, BLEU-3: 0.5220, BLEU-4: 0.5220
# ROUGE-1: 0.7547, ROUGE-2: 0.7451, ROUGE-L: 0.7547
# CIDEr: 0.0000
#
# Sample 279:
# BLEU-1: 0.3067, BLEU-2: 0.3067, BLEU-3: 0.3067, BLEU-4: 0.3067
# ROUGE-1: 0.6286, ROUGE-2: 0.6061, ROUGE-L: 0.6286
# CIDEr: 0.0000
#
# Sample 280:
# BLEU-1: 0.2725, BLEU-2: 0.2725, BLEU-3: 0.2725, BLEU-4: 0.2725
# ROUGE-1: 0.6286, ROUGE-2: 0.6061, ROUGE-L: 0.6286
# CIDEr: 0.0000
#
# Sample 281:
# BLEU-1: 0.5385, BLEU-2: 0.5385, BLEU-3: 0.5385, BLEU-4: 0.5385
# ROUGE-1: 0.7719, ROUGE-2: 0.7636, ROUGE-L: 0.7719
# CIDEr: 0.0000
#
# Sample 282:
# BLEU-1: 0.4437, BLEU-2: 0.4437, BLEU-3: 0.4437, BLEU-4: 0.4437
# ROUGE-1: 0.7111, ROUGE-2: 0.6977, ROUGE-L: 0.7111
# CIDEr: 0.0000
#
# Sample 283:
# BLEU-1: 0.2725, BLEU-2: 0.2725, BLEU-3: 0.2725, BLEU-4: 0.2725
# ROUGE-1: 0.6286, ROUGE-2: 0.6061, ROUGE-L: 0.6286
# CIDEr: 0.0000
#
# Sample 284:
# BLEU-1: 0.2359, BLEU-2: 0.2359, BLEU-3: 0.2359, BLEU-4: 0.2359
# ROUGE-1: 0.5806, ROUGE-2: 0.5517, ROUGE-L: 0.5806
# CIDEr: 0.0000
#
# Sample 285:
# BLEU-1: 0.3067, BLEU-2: 0.3067, BLEU-3: 0.3067, BLEU-4: 0.3067
# ROUGE-1: 0.6486, ROUGE-2: 0.6286, ROUGE-L: 0.6486
# CIDEr: 0.0000
#
# Sample 286:
# BLEU-1: 0.7391, BLEU-2: 0.7391, BLEU-3: 0.7391, BLEU-4: 0.7391
# ROUGE-1: 0.8713, ROUGE-2: 0.8687, ROUGE-L: 0.8713
# CIDEr: 0.0000
#
# Sample 287:
# BLEU-1: 0.1969, BLEU-2: 0.1969, BLEU-3: 0.1969, BLEU-4: 0.1969
# ROUGE-1: 0.5517, ROUGE-2: 0.5185, ROUGE-L: 0.5517
# CIDEr: 0.0000
#
# Sample 288:
# BLEU-1: 0.1969, BLEU-2: 0.1969, BLEU-3: 0.1969, BLEU-4: 0.1969
# ROUGE-1: 0.5517, ROUGE-2: 0.5185, ROUGE-L: 0.5517
# CIDEr: 0.0000
#
# Sample 289:
# BLEU-1: 0.4655, BLEU-2: 0.4655, BLEU-3: 0.4655, BLEU-4: 0.4655
# ROUGE-1: 0.7347, ROUGE-2: 0.7234, ROUGE-L: 0.7347
# CIDEr: 0.0000
#
# Sample 290:
# BLEU-1: 0.7037, BLEU-2: 0.7037, BLEU-3: 0.7037, BLEU-4: 0.7037
# ROUGE-1: 0.8539, ROUGE-2: 0.8506, ROUGE-L: 0.8539
# CIDEr: 0.0000
#
# Sample 291:
# BLEU-1: 0.3951, BLEU-2: 0.3951, BLEU-3: 0.3951, BLEU-4: 0.3951
# ROUGE-1: 0.6667, ROUGE-2: 0.6486, ROUGE-L: 0.6667
# CIDEr: 0.0000
#
# Sample 292:
# BLEU-1: 0.3385, BLEU-2: 0.3385, BLEU-3: 0.3385, BLEU-4: 0.3385
# ROUGE-1: 0.6486, ROUGE-2: 0.6286, ROUGE-L: 0.6486
# CIDEr: 0.0000
#
# Sample 293:
# BLEU-1: 0.4655, BLEU-2: 0.4655, BLEU-3: 0.4655, BLEU-4: 0.4655
# ROUGE-1: 0.7234, ROUGE-2: 0.7111, ROUGE-L: 0.7234
# CIDEr: 0.0000
#
# Sample 294:
# BLEU-1: 0.5220, BLEU-2: 0.5220, BLEU-3: 0.5220, BLEU-4: 0.5220
# ROUGE-1: 0.7547, ROUGE-2: 0.7451, ROUGE-L: 0.7547
# CIDEr: 0.0000
#
# Sample 295:
# BLEU-1: 0.5045, BLEU-2: 0.5045, BLEU-3: 0.5045, BLEU-4: 0.5045
# ROUGE-1: 0.7451, ROUGE-2: 0.7347, ROUGE-L: 0.7451
# CIDEr: 0.0000
#
# Sample 296:
# BLEU-1: 0.1146, BLEU-2: 0.1146, BLEU-3: 0.1146, BLEU-4: 0.1146
# ROUGE-1: 0.5517, ROUGE-2: 0.5185, ROUGE-L: 0.5517
# CIDEr: 0.0000
#
# Sample 297:
# BLEU-1: 0.5682, BLEU-2: 0.5682, BLEU-3: 0.5682, BLEU-4: 0.5682
# ROUGE-1: 0.7937, ROUGE-2: 0.7869, ROUGE-L: 0.7937
# CIDEr: 0.0000
#
# Sample 298:
# BLEU-1: 0.5818, BLEU-2: 0.5818, BLEU-3: 0.5818, BLEU-4: 0.5818
# ROUGE-1: 0.8169, ROUGE-2: 0.8116, ROUGE-L: 0.8169
# CIDEr: 0.0000
#
# Sample 299:
# BLEU-1: 0.4857, BLEU-2: 0.4857, BLEU-3: 0.4857, BLEU-4: 0.4857
# ROUGE-1: 0.7451, ROUGE-2: 0.7347, ROUGE-L: 0.7451
# CIDEr: 0.0000
#
# Sample 300:
# BLEU-1: 0.5045, BLEU-2: 0.5045, BLEU-3: 0.5045, BLEU-4: 0.5045
# ROUGE-1: 0.7451, ROUGE-2: 0.7347, ROUGE-L: 0.7451
# CIDEr: 0.0000
#
# Sample 301:
# BLEU-1: 0.5045, BLEU-2: 0.5045, BLEU-3: 0.5045, BLEU-4: 0.5045
# ROUGE-1: 0.7547, ROUGE-2: 0.7451, ROUGE-L: 0.7547
# CIDEr: 0.0000
#
# Sample 302:
# BLEU-1: 0.2725, BLEU-2: 0.2725, BLEU-3: 0.2725, BLEU-4: 0.2725
# ROUGE-1: 0.6286, ROUGE-2: 0.6061, ROUGE-L: 0.6286
# CIDEr: 0.0000
#
# Sample 303:
# BLEU-1: 0.5945, BLEU-2: 0.5945, BLEU-3: 0.5945, BLEU-4: 0.5945
# ROUGE-1: 0.8000, ROUGE-2: 0.7937, ROUGE-L: 0.8000
# CIDEr: 0.0000
#
# Sample 304:
# BLEU-1: 0.5945, BLEU-2: 0.5945, BLEU-3: 0.5945, BLEU-4: 0.5945
# ROUGE-1: 0.8000, ROUGE-2: 0.7937, ROUGE-L: 0.8000
# CIDEr: 0.0000
#
# Sample 305:
# BLEU-1: 0.7103, BLEU-2: 0.7103, BLEU-3: 0.7103, BLEU-4: 0.7103
# ROUGE-1: 0.8602, ROUGE-2: 0.8571, ROUGE-L: 0.8602
# CIDEr: 0.0000
#
# Sample 306:
# BLEU-1: 0.3385, BLEU-2: 0.3385, BLEU-3: 0.3385, BLEU-4: 0.3385
# ROUGE-1: 0.6486, ROUGE-2: 0.6286, ROUGE-L: 0.6486
# CIDEr: 0.0000
#
# Sample 307:
# BLEU-1: 0.1561, BLEU-2: 0.1561, BLEU-3: 0.1561, BLEU-4: 0.1561
# ROUGE-1: 0.5185, ROUGE-2: 0.4800, ROUGE-L: 0.5185
# CIDEr: 0.0000
#
# Sample 308:
# BLEU-1: 0.6969, BLEU-2: 0.6969, BLEU-3: 0.6969, BLEU-4: 0.6969
# ROUGE-1: 0.8571, ROUGE-2: 0.8539, ROUGE-L: 0.8571
# CIDEr: 0.0000
#
# Sample 309:
# BLEU-1: 0.6661, BLEU-2: 0.6661, BLEU-3: 0.6661, BLEU-4: 0.6661
# ROUGE-1: 0.8312, ROUGE-2: 0.8267, ROUGE-L: 0.8312
# CIDEr: 0.0000
#
# Sample 310:
# BLEU-1: 0.3679, BLEU-2: 0.3679, BLEU-3: 0.3679, BLEU-4: 0.3679
# ROUGE-1: 0.6977, ROUGE-2: 0.6829, ROUGE-L: 0.6977
# CIDEr: 0.0000
#
# Sample 311:
# BLEU-1: 0.5538, BLEU-2: 0.5538, BLEU-3: 0.5538, BLEU-4: 0.5538
# ROUGE-1: 0.7719, ROUGE-2: 0.7636, ROUGE-L: 0.7719
# CIDEr: 0.0000
#
# Sample 312:
# BLEU-1: 0.6483, BLEU-2: 0.6483, BLEU-3: 0.6483, BLEU-4: 0.6483
# ROUGE-1: 0.8219, ROUGE-2: 0.8169, ROUGE-L: 0.8219
# CIDEr: 0.0000
#
# Sample 313:
# BLEU-1: 0.0131, BLEU-2: 0.0131, BLEU-3: 0.0131, BLEU-4: 0.0076
# ROUGE-1: 0.3158, ROUGE-2: 0.2353, ROUGE-L: 0.3158
# CIDEr: 0.0000
#
# Sample 314:
# BLEU-1: 0.6823, BLEU-2: 0.6823, BLEU-3: 0.6823, BLEU-4: 0.6823
# ROUGE-1: 0.8395, ROUGE-2: 0.8354, ROUGE-L: 0.8395
# CIDEr: 0.0000
#
# Sample 315:
# BLEU-1: 0.6286, BLEU-2: 0.6286, BLEU-3: 0.6286, BLEU-4: 0.6286
# ROUGE-1: 0.8267, ROUGE-2: 0.8219, ROUGE-L: 0.8267
# CIDEr: 0.0000
#
# Sample 316:
# BLEU-1: 0.3067, BLEU-2: 0.3067, BLEU-3: 0.3067, BLEU-4: 0.3067
# ROUGE-1: 0.6286, ROUGE-2: 0.6061, ROUGE-L: 0.6286
# CIDEr: 0.0000
#
# Sample 317:
# BLEU-1: 0.6661, BLEU-2: 0.6661, BLEU-3: 0.6661, BLEU-4: 0.6661
# ROUGE-1: 0.8312, ROUGE-2: 0.8267, ROUGE-L: 0.8312
# CIDEr: 0.0000
#
# Sample 318:
# BLEU-1: 0.7538, BLEU-2: 0.7538, BLEU-3: 0.7538, BLEU-4: 0.7538
# ROUGE-1: 0.8785, ROUGE-2: 0.8762, ROUGE-L: 0.8785
# CIDEr: 0.0000
#
# Sample 319:
# BLEU-1: 0.6065, BLEU-2: 0.6065, BLEU-3: 0.6065, BLEU-4: 0.6065
# ROUGE-1: 0.8060, ROUGE-2: 0.8000, ROUGE-L: 0.8060
# CIDEr: 0.0000
#
# Sample 320:
# BLEU-1: 0.6897, BLEU-2: 0.6897, BLEU-3: 0.6897, BLEU-4: 0.6897
# ROUGE-1: 0.8471, ROUGE-2: 0.8434, ROUGE-L: 0.8471
# CIDEr: 0.0000
#
# Sample 321:
# BLEU-1: 0.4857, BLEU-2: 0.4857, BLEU-3: 0.4857, BLEU-4: 0.4857
# ROUGE-1: 0.7347, ROUGE-2: 0.7234, ROUGE-L: 0.7347
# CIDEr: 0.0000
#
# Sample 322:
# BLEU-1: 0.4437, BLEU-2: 0.4437, BLEU-3: 0.4437, BLEU-4: 0.4437
# ROUGE-1: 0.7234, ROUGE-2: 0.7111, ROUGE-L: 0.7234
# CIDEr: 0.0000
#
# Sample 323:
# BLEU-1: 0.2725, BLEU-2: 0.2725, BLEU-3: 0.2725, BLEU-4: 0.2725
# ROUGE-1: 0.6061, ROUGE-2: 0.5806, ROUGE-L: 0.6061
# CIDEr: 0.0000
#
# Sample 324:
# BLEU-1: 0.5682, BLEU-2: 0.5682, BLEU-3: 0.5682, BLEU-4: 0.5682
# ROUGE-1: 0.7451, ROUGE-2: 0.7347, ROUGE-L: 0.7451
# CIDEr: 0.0000
#
# Sample 325:
# BLEU-1: 0.2359, BLEU-2: 0.2359, BLEU-3: 0.2359, BLEU-4: 0.2359
# ROUGE-1: 0.6286, ROUGE-2: 0.6061, ROUGE-L: 0.6286
# CIDEr: 0.0000
#
# Sample 326:
# BLEU-1: 0.4857, BLEU-2: 0.4857, BLEU-3: 0.4857, BLEU-4: 0.4857
# ROUGE-1: 0.7451, ROUGE-2: 0.7347, ROUGE-L: 0.7451
# CIDEr: 0.0000
#
# Sample 327:
# BLEU-1: 0.3067, BLEU-2: 0.3067, BLEU-3: 0.3067, BLEU-4: 0.3067
# ROUGE-1: 0.6286, ROUGE-2: 0.6061, ROUGE-L: 0.6286
# CIDEr: 0.0000
#
# Sample 328:
# BLEU-1: 0.5818, BLEU-2: 0.5818, BLEU-3: 0.5818, BLEU-4: 0.5818
# ROUGE-1: 0.7636, ROUGE-2: 0.7547, ROUGE-L: 0.7636
# CIDEr: 0.0000
#
# Sample 329:
# BLEU-1: 0.7103, BLEU-2: 0.7103, BLEU-3: 0.7103, BLEU-4: 0.7103
# ROUGE-1: 0.8571, ROUGE-2: 0.8539, ROUGE-L: 0.8571
# CIDEr: 0.0000
#
# Sample 330:
# BLEU-1: 0.4204, BLEU-2: 0.4204, BLEU-3: 0.4204, BLEU-4: 0.4204
# ROUGE-1: 0.6977, ROUGE-2: 0.6829, ROUGE-L: 0.6977
# CIDEr: 0.0000
#
# Sample 331:
# BLEU-1: 0.3951, BLEU-2: 0.3951, BLEU-3: 0.3951, BLEU-4: 0.3951
# ROUGE-1: 0.6667, ROUGE-2: 0.6486, ROUGE-L: 0.6667
# CIDEr: 0.0000
#
# Sample 332:
# BLEU-1: 0.1969, BLEU-2: 0.1969, BLEU-3: 0.1969, BLEU-4: 0.1969
# ROUGE-1: 0.5517, ROUGE-2: 0.5185, ROUGE-L: 0.5517
# CIDEr: 0.0000
#
# Sample 333:
# BLEU-1: 0.6897, BLEU-2: 0.6897, BLEU-3: 0.6897, BLEU-4: 0.6897
# ROUGE-1: 0.8434, ROUGE-2: 0.8395, ROUGE-L: 0.8434
# CIDEr: 0.0000
#
# Sample 334:
# BLEU-1: 0.6065, BLEU-2: 0.6065, BLEU-3: 0.6065, BLEU-4: 0.6065
# ROUGE-1: 0.8000, ROUGE-2: 0.7937, ROUGE-L: 0.8000
# CIDEr: 0.0000
#
# Sample 335:
# BLEU-1: 0.3385, BLEU-2: 0.3385, BLEU-3: 0.3385, BLEU-4: 0.3385
# ROUGE-1: 0.6667, ROUGE-2: 0.6486, ROUGE-L: 0.6667
# CIDEr: 0.0000
#
# Sample 336:
# BLEU-1: 0.3385, BLEU-2: 0.3385, BLEU-3: 0.3385, BLEU-4: 0.3385
# ROUGE-1: 0.6667, ROUGE-2: 0.6486, ROUGE-L: 0.6667
# CIDEr: 0.0000
#
# Sample 337:
# BLEU-1: 0.2359, BLEU-2: 0.2359, BLEU-3: 0.2359, BLEU-4: 0.2359
# ROUGE-1: 0.4348, ROUGE-2: 0.3810, ROUGE-L: 0.4348
# CIDEr: 0.0000
#
# Sample 338:
# BLEU-1: 0.6744, BLEU-2: 0.6744, BLEU-3: 0.6744, BLEU-4: 0.6744
# ROUGE-1: 0.8434, ROUGE-2: 0.8395, ROUGE-L: 0.8434
# CIDEr: 0.0000
#
# Sample 339:
# BLEU-1: 0.6483, BLEU-2: 0.6483, BLEU-3: 0.6483, BLEU-4: 0.6483
# ROUGE-1: 0.8169, ROUGE-2: 0.8116, ROUGE-L: 0.8169
# CIDEr: 0.0000
#
# Sample 340:
# BLEU-1: 0.3951, BLEU-2: 0.3951, BLEU-3: 0.3951, BLEU-4: 0.3951
# ROUGE-1: 0.6829, ROUGE-2: 0.6667, ROUGE-L: 0.6829
# CIDEr: 0.0000
#
# Sample 341:
# BLEU-1: 0.2359, BLEU-2: 0.2359, BLEU-3: 0.2359, BLEU-4: 0.2359
# ROUGE-1: 0.5517, ROUGE-2: 0.5185, ROUGE-L: 0.5517
# CIDEr: 0.0000
#
# Sample 342:
# BLEU-1: 0.4857, BLEU-2: 0.4857, BLEU-3: 0.4857, BLEU-4: 0.4857
# ROUGE-1: 0.7347, ROUGE-2: 0.7234, ROUGE-L: 0.7347
# CIDEr: 0.0000
#
# Sample 343:
# BLEU-1: 0.5385, BLEU-2: 0.5385, BLEU-3: 0.5385, BLEU-4: 0.5385
# ROUGE-1: 0.7636, ROUGE-2: 0.7547, ROUGE-L: 0.7636
# CIDEr: 0.0000
#
# Sample 344:
# BLEU-1: 0.5385, BLEU-2: 0.5385, BLEU-3: 0.5385, BLEU-4: 0.5385
# ...
# CIDEr: 0.0000
#
# Sample 387:
# BLEU-1: 0.6286, BLEU-2: 0.6286, BLEU-3: 0.6286, BLEU-4: 0.6286
# ROUGE-1: 0.8116, ROUGE-2: 0.8060, ROUGE-L: 0.8116
# CIDEr: 0.0000
#
# Sample 388:
# BLEU-1: 0.2725, BLEU-2: 0.2725, BLEU-3: 0.2725, BLEU-4: 0.2725
# ROUGE-1: 0.6061, ROUGE-2: 0.5806, ROUGE-L: 0.6061
# CIDEr: 0.0000
#
# Sample 389:
# BLEU-1: 0.6065, BLEU-2: 0.6065, BLEU-3: 0.6065, BLEU-4: 0.6065
# ROUGE-1: 0.8060, ROUGE-2: 0.8000, ROUGE-L: 0.8060
# CIDEr: 0.0000
#
# Sample 390:
# BLEU-1: 0.6483, BLEU-2: 0.6483, BLEU-3: 0.6483, BLEU-4: 0.6483
# ROUGE-1: 0.8169, ROUGE-2: 0.8116, ROUGE-L: 0.8169
# CIDEr: 0.0000
#
# Sample 391:
# BLEU-1: 0.2725, BLEU-2: 0.2725, BLEU-3: 0.2725, BLEU-4: 0.2725
# ROUGE-1: 0.6061, ROUGE-2: 0.5806, ROUGE-L: 0.6061
# CIDEr: 0.0000
#
# Sample 392:
# BLEU-1: 0.6575, BLEU-2: 0.6575, BLEU-3: 0.6575, BLEU-4: 0.6575
# ROUGE-1: 0.8267, ROUGE-2: 0.8219, ROUGE-L: 0.8267
# CIDEr: 0.0000
#
# Sample 393:
# BLEU-1: 0.4655, BLEU-2: 0.4655, BLEU-3: 0.4655, BLEU-4: 0.4655
# ROUGE-1: 0.7347, ROUGE-2: 0.7234, ROUGE-L: 0.7347
# CIDEr: 0.0000
#
# Sample 394:
# BLEU-1: 0.3951, BLEU-2: 0.3951, BLEU-3: 0.3951, BLEU-4: 0.3951
# ROUGE-1: 0.6829, ROUGE-2: 0.6667, ROUGE-L: 0.6829
# CIDEr: 0.0000
#
# Sample 395:
# BLEU-1: 0.7860, BLEU-2: 0.7860, BLEU-3: 0.7860, BLEU-4: 0.7860
# ROUGE-1: 0.8926, ROUGE-2: 0.8908, ROUGE-L: 0.8926
# CIDEr: 0.0000
#
# Sample 396:
# BLEU-1: 0.7338, BLEU-2: 0.7338, BLEU-3: 0.7338, BLEU-4: 0.7338
# ROUGE-1: 0.8632, ROUGE-2: 0.8602, ROUGE-L: 0.8632
# CIDEr: 0.0000
#
# Sample 397:
# BLEU-1: 0.1146, BLEU-2: 0.1146, BLEU-3: 0.1146, BLEU-4: 0.1146
# ROUGE-1: 0.4800, ROUGE-2: 0.4348, ROUGE-L: 0.4800
# CIDEr: 0.0000
#
# Sample 398:
# BLEU-1: 0.2359, BLEU-2: 0.2359, BLEU-3: 0.2359, BLEU-4: 0.2359
# ROUGE-1: 0.6061, ROUGE-2: 0.5806, ROUGE-L: 0.6061
# CIDEr: 0.0000
#
# Sample 399:
# BLEU-1: 0.6286, BLEU-2: 0.6286, BLEU-3: 0.6286, BLEU-4: 0.6286
# ROUGE-1: 0.8000, ROUGE-2: 0.7937, ROUGE-L: 0.8000
# CIDEr: 0.0000
#
# Sample 400:
# BLEU-1: 0.7584, BLEU-2: 0.7584, BLEU-3: 0.7584, BLEU-4: 0.7584
# ROUGE-1: 0.8785, ROUGE-2: 0.8762, ROUGE-L: 0.8785
# CIDEr: 0.0000
#
# Sample 401:
# BLEU-1: 0.1969, BLEU-2: 0.1969, BLEU-3: 0.1969, BLEU-4: 0.1969
# ROUGE-1: 0.5806, ROUGE-2: 0.5517, ROUGE-L: 0.5806
# CIDEr: 0.0000
#
# Sample 402:
# BLEU-1: 0.7442, BLEU-2: 0.7442, BLEU-3: 0.7442, BLEU-4: 0.7442
# ROUGE-1: 0.8762, ROUGE-2: 0.8738, ROUGE-L: 0.8762
# CIDEr: 0.0000
#
# Sample 403:
# BLEU-1: 0.4857, BLEU-2: 0.4857, BLEU-3: 0.4857, BLEU-4: 0.4857
# ROUGE-1: 0.7347, ROUGE-2: 0.7234, ROUGE-L: 0.7347
# CIDEr: 0.0000
#
# Sample 404:
# BLEU-1: 0.3679, BLEU-2: 0.3679, BLEU-3: 0.3679, BLEU-4: 0.3679
# ROUGE-1: 0.6667, ROUGE-2: 0.6486, ROUGE-L: 0.6667
# CIDEr: 0.0000
#
# Sample 405:
# BLEU-1: 0.6065, BLEU-2: 0.6065, BLEU-3: 0.6065, BLEU-4: 0.6065
# ROUGE-1: 0.8000, ROUGE-2: 0.7937, ROUGE-L: 0.8000
# CIDEr: 0.0000
#
# Sample 406:
# BLEU-1: 0.5045, BLEU-2: 0.5045, BLEU-3: 0.5045, BLEU-4: 0.5045
# ROUGE-1: 0.7547, ROUGE-2: 0.7451, ROUGE-L: 0.7547
# CIDEr: 0.0000
#
# Sample 407:
# BLEU-1: 0.6065, BLEU-2: 0.6065, BLEU-3: 0.6065, BLEU-4: 0.6065
# ROUGE-1: 0.8060, ROUGE-2: 0.8000, ROUGE-L: 0.8060
# CIDEr: 0.0000
#
# Sample 408:
# BLEU-1: 0.7538, BLEU-2: 0.7538, BLEU-3: 0.7538, BLEU-4: 0.7538
# ROUGE-1: 0.8785, ROUGE-2: 0.8762, ROUGE-L: 0.8785
# CIDEr: 0.0000
#
# Sample 409:
# BLEU-1: 0.6575, BLEU-2: 0.6575, BLEU-3: 0.6575, BLEU-4: 0.6575
# ROUGE-1: 0.8354, ROUGE-2: 0.8312, ROUGE-L: 0.8354
# CIDEr: 0.0000
#
# Sample 410:
# BLEU-1: 0.6575, BLEU-2: 0.6575, BLEU-3: 0.6575, BLEU-4: 0.6575
# ROUGE-1: 0.8312, ROUGE-2: 0.8267, ROUGE-L: 0.8312
# CIDEr: 0.0000
#
# Sample 411:
# BLEU-1: 0.6897, BLEU-2: 0.6897, BLEU-3: 0.6897, BLEU-4: 0.6897
# ROUGE-1: 0.8506, ROUGE-2: 0.8471, ROUGE-L: 0.8506
# CIDEr: 0.0000
#
# Sample 412:
# BLEU-1: 0.7103, BLEU-2: 0.7103, BLEU-3: 0.7103, BLEU-4: 0.7103
# ROUGE-1: 0.8506, ROUGE-2: 0.8471, ROUGE-L: 0.8506
# CIDEr: 0.0000
#
# Sample 413:
# BLEU-1: 0.5538, BLEU-2: 0.5538, BLEU-3: 0.5538, BLEU-4: 0.5538
# ROUGE-1: 0.7719, ROUGE-2: 0.7636, ROUGE-L: 0.7719
# CIDEr: 0.0000
#
# Sample 414:
# BLEU-1: 0.6969, BLEU-2: 0.6969, BLEU-3: 0.6969, BLEU-4: 0.6969
# ROUGE-1: 0.8506, ROUGE-2: 0.8471, ROUGE-L: 0.8506
# CIDEr: 0.0000
#
# Sample 415:
# BLEU-1: 0.3679, BLEU-2: 0.3679, BLEU-3: 0.3679, BLEU-4: 0.3679
# ROUGE-1: 0.6667, ROUGE-2: 0.6486, ROUGE-L: 0.6667
# CIDEr: 0.0000
#
# Sample 416:
# BLEU-1: 0.6969, BLEU-2: 0.6969, BLEU-3: 0.6969, BLEU-4: 0.6969
# ROUGE-1: 0.8471, ROUGE-2: 0.8434, ROUGE-L: 0.8471
# CIDEr: 0.0000
#
# Sample 417:
# BLEU-1: 0.1146, BLEU-2: 0.1146, BLEU-3: 0.1146, BLEU-4: 0.1146
# ROUGE-1: 0.4800, ROUGE-2: 0.4348, ROUGE-L: 0.4800
# CIDEr: 0.0000
#
# Sample 418:
# BLEU-1: 0.4655, BLEU-2: 0.4655, BLEU-3: 0.4655, BLEU-4: 0.4655
# ROUGE-1: 0.7347, ROUGE-2: 0.7234, ROUGE-L: 0.7347
# CIDEr: 0.0000
#
# Sample 419:
# BLEU-1: 0.4857, BLEU-2: 0.4857, BLEU-3: 0.4857, BLEU-4: 0.4857
# ROUGE-1: 0.7347, ROUGE-2: 0.7234, ROUGE-L: 0.7347
# CIDEr: 0.0000
#
# Sample 420:
# BLEU-1: 0.7491, BLEU-2: 0.7491, BLEU-3: 0.7491, BLEU-4: 0.7491
# ROUGE-1: 0.8713, ROUGE-2: 0.8687, ROUGE-L: 0.8713
# CIDEr: 0.0000
#
# Sample 421:
# BLEU-1: 0.7225, BLEU-2: 0.7225, BLEU-3: 0.7225, BLEU-4: 0.7225
# ROUGE-1: 0.8602, ROUGE-2: 0.8571, ROUGE-L: 0.8602
# CIDEr: 0.0000
#
# Sample 422:
# BLEU-1: 0.7391, BLEU-2: 0.7391, BLEU-3: 0.7391, BLEU-4: 0.7391
# ROUGE-1: 0.8687, ROUGE-2: 0.8660, ROUGE-L: 0.8687
# CIDEr: 0.0000
#
# Sample 423:
# BLEU-1: 0.2725, BLEU-2: 0.2725, BLEU-3: 0.2725, BLEU-4: 0.2725
# ROUGE-1: 0.6061, ROUGE-2: 0.5806, ROUGE-L: 0.6061
# CIDEr: 0.0000
#
# Sample 424:
# BLEU-1: 0.1969, BLEU-2: 0.1969, BLEU-3: 0.1969, BLEU-4: 0.1969
# ROUGE-1: 0.5517, ROUGE-2: 0.5185, ROUGE-L: 0.5517
# CIDEr: 0.0000
#
# Sample 425:
# BLEU-1: 0.6661, BLEU-2: 0.6661, BLEU-3: 0.6661, BLEU-4: 0.6661
# ROUGE-1: 0.8354, ROUGE-2: 0.8312, ROUGE-L: 0.8354
# CIDEr: 0.0000
#
# Sample 426:
# BLEU-1: 0.2725, BLEU-2: 0.2725, BLEU-3: 0.2725, BLEU-4: 0.2725
# ROUGE-1: 0.6286, ROUGE-2: 0.6061, ROUGE-L: 0.6286
# CIDEr: 0.0000
#
# Sample 427:
# BLEU-1: 0.3067, BLEU-2: 0.3067, BLEU-3: 0.3067, BLEU-4: 0.3067
# ROUGE-1: 0.6286, ROUGE-2: 0.6061, ROUGE-L: 0.6286
# CIDEr: 0.0000
#
# Sample 428:
# BLEU-1: 0.5385, BLEU-2: 0.5385, BLEU-3: 0.5385, BLEU-4: 0.5385
# ROUGE-1: 0.7451, ROUGE-2: 0.7347, ROUGE-L: 0.7451
# CIDEr: 0.0000
#
# Sample 429:
# BLEU-1: 0.6897, BLEU-2: 0.6897, BLEU-3: 0.6897, BLEU-4: 0.6897
# ROUGE-1: 0.8312, ROUGE-2: 0.8267, ROUGE-L: 0.8312
# CIDEr: 0.0000
#
# Sample 430:
# BLEU-1: 0.0087, BLEU-2: 0.0087, BLEU-3: 0.0087, BLEU-4: 0.0087
# ROUGE-1: 0.2963, ROUGE-2: 0.2400, ROUGE-L: 0.2963
# CIDEr: 0.0000
#
# Sample 431:
# BLEU-1: 0.7225, BLEU-2: 0.7225, BLEU-3: 0.7225, BLEU-4: 0.7225
# ROUGE-1: 0.8687, ROUGE-2: 0.8660, ROUGE-L: 0.8687
# CIDEr: 0.0000
#
# Sample 432:
# BLEU-1: 0.3679, BLEU-2: 0.3679, BLEU-3: 0.3679, BLEU-4: 0.3679
# ROUGE-1: 0.6977, ROUGE-2: 0.6829, ROUGE-L: 0.6977
# CIDEr: 0.0000
#
# Sample 433:
# BLEU-1: 0.6483, BLEU-2: 0.6483, BLEU-3: 0.6483, BLEU-4: 0.6483
# ROUGE-1: 0.8116, ROUGE-2: 0.8060, ROUGE-L: 0.8116
# CIDEr: 0.0000
#
# Sample 434:
# BLEU-1: 0.3679, BLEU-2: 0.3679, BLEU-3: 0.3679, BLEU-4: 0.3679
# ROUGE-1: 0.6829, ROUGE-2: 0.6667, ROUGE-L: 0.6829
# CIDEr: 0.0000
#
# Sample 435:
# BLEU-1: 0.4204, BLEU-2: 0.4204, BLEU-3: 0.4204, BLEU-4: 0.4204
# ROUGE-1: 0.7111, ROUGE-2: 0.6977, ROUGE-L: 0.7111
# CIDEr: 0.0000
#
# Sample 436:
# BLEU-1: 0.6575, BLEU-2: 0.6575, BLEU-3: 0.6575, BLEU-4: 0.6575
# ROUGE-1: 0.8312, ROUGE-2: 0.8267, ROUGE-L: 0.8312
# CIDEr: 0.0000
#
# Sample 437:
# BLEU-1: 0.7538, BLEU-2: 0.7538, BLEU-3: 0.7538, BLEU-4: 0.7538
# ROUGE-1: 0.8807, ROUGE-2: 0.8785, ROUGE-L: 0.8807
# CIDEr: 0.0000
#
# Sample 438:
# BLEU-1: 0.3385, BLEU-2: 0.3385, BLEU-3: 0.3385, BLEU-4: 0.3385
# ROUGE-1: 0.6486, ROUGE-2: 0.6286, ROUGE-L: 0.6486
# CIDEr: 0.0000
#
# Sample 439:
# BLEU-1: 0.6483, BLEU-2: 0.6483, BLEU-3: 0.6483, BLEU-4: 0.6483
# ROUGE-1: 0.8267, ROUGE-2: 0.8219, ROUGE-L: 0.8267
# CIDEr: 0.0000
#
# Sample 440:
# BLEU-1: 0.1561, BLEU-2: 0.1561, BLEU-3: 0.1561, BLEU-4: 0.1561
# ROUGE-1: 0.3810, ROUGE-2: 0.3158, ROUGE-L: 0.3810
# CIDEr: 0.0000
#
# Sample 441:
# BLEU-1: 0.6744, BLEU-2: 0.6744, BLEU-3: 0.6744, BLEU-4: 0.6744
# ROUGE-1: 0.8395, ROUGE-2: 0.8354, ROUGE-L: 0.8395
# CIDEr: 0.0000
#
# Sample 442:
# BLEU-1: 0.3067, BLEU-2: 0.3067, BLEU-3: 0.3067, BLEU-4: 0.3067
# ROUGE-1: 0.6286, ROUGE-2: 0.6061, ROUGE-L: 0.6286
# CIDEr: 0.0000
#
# Sample 443:
# BLEU-1: 0.3067, BLEU-2: 0.3067, BLEU-3: 0.3067, BLEU-4: 0.3067
# ROUGE-1: 0.5806, ROUGE-2: 0.5517, ROUGE-L: 0.5806
# CIDEr: 0.0000
#
# Sample 444:
# BLEU-1: 0.6575, BLEU-2: 0.6575, BLEU-3: 0.6575, BLEU-4: 0.6575
# ROUGE-1: 0.8219, ROUGE-2: 0.8169, ROUGE-L: 0.8219
# CIDEr: 0.0000
#
# Sample 445:
# BLEU-1: 0.7283, BLEU-2: 0.7283, BLEU-3: 0.7283, BLEU-4: 0.7283
# ROUGE-1: 0.8602, ROUGE-2: 0.8571, ROUGE-L: 0.8602
# CIDEr: 0.0000
#
# Sample 446:
# BLEU-1: 0.5385, BLEU-2: 0.5385, BLEU-3: 0.5385, BLEU-4: 0.5385
# ROUGE-1: 0.7547, ROUGE-2: 0.7451, ROUGE-L: 0.7547
# CIDEr: 0.0000
#
# Sample 447:
# BLEU-1: 0.6387, BLEU-2: 0.6387, BLEU-3: 0.6387, BLEU-4: 0.6387
# ROUGE-1: 0.8060, ROUGE-2: 0.8000, ROUGE-L: 0.8060
# CIDEr: 0.0000
#
# Sample 448:
# BLEU-1: 0.7491, BLEU-2: 0.7491, BLEU-3: 0.7491, BLEU-4: 0.7491
# ROUGE-1: 0.8713, ROUGE-2: 0.8687, ROUGE-L: 0.8713
# CIDEr: 0.0000
#
# Sample 449:
# BLEU-1: 0.4204, BLEU-2: 0.4204, BLEU-3: 0.4204, BLEU-4: 0.4204
# ROUGE-1: 0.6286, ROUGE-2: 0.6061, ROUGE-L: 0.6286
# CIDEr: 0.0000
#
# Sample 450:
# BLEU-1: 0.6575, BLEU-2: 0.6575, BLEU-3: 0.6575, BLEU-4: 0.6575
# ROUGE-1: 0.8267, ROUGE-2: 0.8219, ROUGE-L: 0.8267
# CIDEr: 0.0000
#
# Sample 451:
# BLEU-1: 0.7037, BLEU-2: 0.7037, BLEU-3: 0.7037, BLEU-4: 0.7037
# ROUGE-1: 0.8571, ROUGE-2: 0.8539, ROUGE-L: 0.8571
# CIDEr: 0.0000
#
# Sample 452:
# BLEU-1: 0.3067, BLEU-2: 0.3067, BLEU-3: 0.3067, BLEU-4: 0.3067
# ROUGE-1: 0.6286, ROUGE-2: 0.6061, ROUGE-L: 0.6286
# CIDEr: 0.0000
#
# Sample 453:
# BLEU-1: 0.5220, BLEU-2: 0.5220, BLEU-3: 0.5220, BLEU-4: 0.5220
# ROUGE-1: 0.7797, ROUGE-2: 0.7719, ROUGE-L: 0.7797
# CIDEr: 0.0000
#
# Sample 454:
# BLEU-1: 0.4204, BLEU-2: 0.4204, BLEU-3: 0.4204, BLEU-4: 0.4204
# ROUGE-1: 0.7111, ROUGE-2: 0.6977, ROUGE-L: 0.7111
# CIDEr: 0.0000
#
# Sample 455:
# BLEU-1: 0.2725, BLEU-2: 0.2725, BLEU-3: 0.2725, BLEU-4: 0.2725
# ROUGE-1: 0.6061, ROUGE-2: 0.5806, ROUGE-L: 0.6061
# CIDEr: 0.0000
#
# Sample 456:
# BLEU-1: 0.3679, BLEU-2: 0.3679, BLEU-3: 0.3679, BLEU-4: 0.3679
# ROUGE-1: 0.6286, ROUGE-2: 0.6061, ROUGE-L: 0.6286
# CIDEr: 0.0000
#
# Sample 457:
# BLEU-1: 0.5682, BLEU-2: 0.5682, BLEU-3: 0.5682, BLEU-4: 0.5682
# ROUGE-1: 0.7797, ROUGE-2: 0.7719, ROUGE-L: 0.7797
# CIDEr: 0.0000
#
# Sample 458:
# BLEU-1: 0.1561, BLEU-2: 0.1561, BLEU-3: 0.1561, BLEU-4: 0.1561
# ROUGE-1: 0.5806, ROUGE-2: 0.5517, ROUGE-L: 0.5806
# CIDEr: 0.0000
#
# Sample 459:
# BLEU-1: 0.7491, BLEU-2: 0.7491, BLEU-3: 0.7491, BLEU-4: 0.7491
# ROUGE-1: 0.8762, ROUGE-2: 0.8738, ROUGE-L: 0.8762
# CIDEr: 0.0000
#
# Sample 460:
# BLEU-1: 0.5385, BLEU-2: 0.5385, BLEU-3: 0.5385, BLEU-4: 0.5385
# ROUGE-1: 0.7636, ROUGE-2: 0.7547, ROUGE-L: 0.7636
# CIDEr: 0.0000
#
# Sample 461:
# BLEU-1: 0.3951, BLEU-2: 0.3951, BLEU-3: 0.3951, BLEU-4: 0.3951
# ROUGE-1: 0.7111, ROUGE-2: 0.6977, ROUGE-L: 0.7111
# CIDEr: 0.0000
#
# Sample 462:
# BLEU-1: 0.4437, BLEU-2: 0.4437, BLEU-3: 0.4437, BLEU-4: 0.4437
# ROUGE-1: 0.7111, ROUGE-2: 0.6977, ROUGE-L: 0.7111
# CIDEr: 0.0000
#
# Sample 463:
# BLEU-1: 0.2359, BLEU-2: 0.2359, BLEU-3: 0.2359, BLEU-4: 0.2359
# ROUGE-1: 0.5806, ROUGE-2: 0.5517, ROUGE-L: 0.5806
# CIDEr: 0.0000
#
# Sample 464:
# BLEU-1: 0.6286, BLEU-2: 0.6286, BLEU-3: 0.6286, BLEU-4: 0.6286
# ROUGE-1: 0.8169, ROUGE-2: 0.8116, ROUGE-L: 0.8169
# CIDEr: 0.0000
#
# Sample 465:
# BLEU-1: 0.1969, BLEU-2: 0.1969, BLEU-3: 0.1969, BLEU-4: 0.1969
# ROUGE-1: 0.5517, ROUGE-2: 0.5185, ROUGE-L: 0.5517
# CIDEr: 0.0000
#
# Sample 466:
# BLEU-1: 0.7391, BLEU-2: 0.7391, BLEU-3: 0.7391, BLEU-4: 0.7391
# ROUGE-1: 0.8713, ROUGE-2: 0.8687, ROUGE-L: 0.8713
# CIDEr: 0.0000
#
# Sample 467:
# BLEU-1: 0.6483, BLEU-2: 0.6483, BLEU-3: 0.6483, BLEU-4: 0.6483
# ROUGE-1: 0.8312, ROUGE-2: 0.8267, ROUGE-L: 0.8312
# CIDEr: 0.0000
#
# Sample 468:
# BLEU-1: 0.7750, BLEU-2: 0.7750, BLEU-3: 0.7750, BLEU-4: 0.7750
# ROUGE-1: 0.8870, ROUGE-2: 0.8850, ROUGE-L: 0.8870
# CIDEr: 0.0000
#
# Sample 469:
# BLEU-1: 0.1561, BLEU-2: 0.1561, BLEU-3: 0.1561, BLEU-4: 0.1561
# ROUGE-1: 0.5185, ROUGE-2: 0.4800, ROUGE-L: 0.5185
# CIDEr: 0.0000
#
# Sample 470:
# BLEU-1: 0.6483, BLEU-2: 0.6483, BLEU-3: 0.6483, BLEU-4: 0.6483
# ROUGE-1: 0.8267, ROUGE-2: 0.8219, ROUGE-L: 0.8267
# CIDEr: 0.0000
#
# Sample 471:
# BLEU-1: 0.3679, BLEU-2: 0.3679, BLEU-3: 0.3679, BLEU-4: 0.3679
# ROUGE-1: 0.6667, ROUGE-2: 0.6486, ROUGE-L: 0.6667
# CIDEr: 0.0000
#
# Sample 472:
# BLEU-1: 0.3951, BLEU-2: 0.3951, BLEU-3: 0.3951, BLEU-4: 0.3951
# ROUGE-1: 0.6977, ROUGE-2: 0.6829, ROUGE-L: 0.6977
# CIDEr: 0.0000
#
# Sample 473:
# BLEU-1: 0.4204, BLEU-2: 0.4204, BLEU-3: 0.4204, BLEU-4: 0.4204
# ROUGE-1: 0.7111, ROUGE-2: 0.6977, ROUGE-L: 0.7111
# CIDEr: 0.0000
#
# Sample 474:
# BLEU-1: 0.3951, BLEU-2: 0.3951, BLEU-3: 0.3951, BLEU-4: 0.3951
# ROUGE-1: 0.6829, ROUGE-2: 0.6667, ROUGE-L: 0.6829
# CIDEr: 0.0000
#
# Sample 475:
# BLEU-1: 0.7165, BLEU-2: 0.7165, BLEU-3: 0.7165, BLEU-4: 0.7165
# ROUGE-1: 0.8602, ROUGE-2: 0.8571, ROUGE-L: 0.8602
# CIDEr: 0.0000
#
# Sample 476:
# BLEU-1: 0.4204, BLEU-2: 0.4204, BLEU-3: 0.4204, BLEU-4: 0.4204
# ROUGE-1: 0.7234, ROUGE-2: 0.7111, ROUGE-L: 0.7234
# CIDEr: 0.0000
#
# Sample 477:
# BLEU-1: 0.7627, BLEU-2: 0.7627, BLEU-3: 0.7627, BLEU-4: 0.7627
# ROUGE-1: 0.8829, ROUGE-2: 0.8807, ROUGE-L: 0.8829
# CIDEr: 0.0000
#
# Sample 478:
# BLEU-1: 0.6661, BLEU-2: 0.6661, BLEU-3: 0.6661, BLEU-4: 0.6661
# ROUGE-1: 0.8312, ROUGE-2: 0.8267, ROUGE-L: 0.8312
# CIDEr: 0.0000
#
# Sample 479:
# BLEU-1: 0.2359, BLEU-2: 0.2359, BLEU-3: 0.2359, BLEU-4: 0.2359
# ROUGE-1: 0.5806, ROUGE-2: 0.5517, ROUGE-L: 0.5806
# CIDEr: 0.0000
#
# Sample 480:
# BLEU-1: 0.5385, BLEU-2: 0.5385, BLEU-3: 0.5385, BLEU-4: 0.5385
# ROUGE-1: 0.7719, ROUGE-2: 0.7636, ROUGE-L: 0.7719
# CIDEr: 0.0000
#
# Sample 481:
# BLEU-1: 0.5945, BLEU-2: 0.5945, BLEU-3: 0.5945, BLEU-4: 0.5945
# ROUGE-1: 0.7937, ROUGE-2: 0.7869, ROUGE-L: 0.7937
# CIDEr: 0.0000
#
# Sample 482:
# BLEU-1: 0.4437, BLEU-2: 0.4437, BLEU-3: 0.4437, BLEU-4: 0.4437
# ROUGE-1: 0.6977, ROUGE-2: 0.6829, ROUGE-L: 0.6977
# CIDEr: 0.0000
#
# Sample 483:
# BLEU-1: 0.2359, BLEU-2: 0.2359, BLEU-3: 0.2359, BLEU-4: 0.2359
# ROUGE-1: 0.5806, ROUGE-2: 0.5517, ROUGE-L: 0.5806
# CIDEr: 0.0000
#
# Sample 484:
# BLEU-1: 0.1146, BLEU-2: 0.1146, BLEU-3: 0.1146, BLEU-4: 0.1146
# ROUGE-1: 0.4800, ROUGE-2: 0.4348, ROUGE-L: 0.4800
# CIDEr: 0.0000
#
# Sample 485:
# BLEU-1: 0.3679, BLEU-2: 0.3679, BLEU-3: 0.3679, BLEU-4: 0.3679
# ROUGE-1: 0.6829, ROUGE-2: 0.6667, ROUGE-L: 0.6829
# CIDEr: 0.0000
#
# Sample 486:
# BLEU-1: 0.1146, BLEU-2: 0.1146, BLEU-3: 0.1146, BLEU-4: 0.1146
# ROUGE-1: 0.4800, ROUGE-2: 0.4348, ROUGE-L: 0.4800
# CIDEr: 0.0000
#
# Sample 487:
# BLEU-1: 0.4655, BLEU-2: 0.4655, BLEU-3: 0.4655, BLEU-4: 0.4655
# ROUGE-1: 0.6977, ROUGE-2: 0.6829, ROUGE-L: 0.6977
# CIDEr: 0.0000
#
# Sample 488:
# BLEU-1: 0.3067, BLEU-2: 0.3067, BLEU-3: 0.3067, BLEU-4: 0.3067
# ROUGE-1: 0.6486, ROUGE-2: 0.6286, ROUGE-L: 0.6486
# CIDEr: 0.0000
#
# Sample 489:
# BLEU-1: 0.4437, BLEU-2: 0.4437, BLEU-3: 0.4437, BLEU-4: 0.4437
# ROUGE-1: 0.6977, ROUGE-2: 0.6829, ROUGE-L: 0.6977
# CIDEr: 0.0000
#
# Sample 490:
# BLEU-1: 0.3385, BLEU-2: 0.3385, BLEU-3: 0.3385, BLEU-4: 0.3385
# ROUGE-1: 0.6667, ROUGE-2: 0.6486, ROUGE-L: 0.6667
# CIDEr: 0.0000
#
# Sample 491:
# BLEU-1: 0.5818, BLEU-2: 0.5818, BLEU-3: 0.5818, BLEU-4: 0.5818
# ROUGE-1: 0.7869, ROUGE-2: 0.7797, ROUGE-L: 0.7869
# CIDEr: 0.0000
#
# Sample 492:
# BLEU-1: 0.7338, BLEU-2: 0.7338, BLEU-3: 0.7338, BLEU-4: 0.7338
# ROUGE-1: 0.8687, ROUGE-2: 0.8660, ROUGE-L: 0.8687
# CIDEr: 0.0000
#
# Sample 493:
# BLEU-1: 0.6575, BLEU-2: 0.6575, BLEU-3: 0.6575, BLEU-4: 0.6575
# ROUGE-1: 0.8219, ROUGE-2: 0.8169, ROUGE-L: 0.8219
# CIDEr: 0.0000
#
# Sample 494:
# BLEU-1: 0.2359, BLEU-2: 0.2359, BLEU-3: 0.2359, BLEU-4: 0.2359
# ROUGE-1: 0.5806, ROUGE-2: 0.5517, ROUGE-L: 0.5806
# CIDEr: 0.0000
#
# Sample 495:
# BLEU-1: 0.4204, BLEU-2: 0.4204, BLEU-3: 0.4204, BLEU-4: 0.4204
# ROUGE-1: 0.6977, ROUGE-2: 0.6829, ROUGE-L: 0.6977
# CIDEr: 0.0000
#
# Sample 496:
# BLEU-1: 0.6744, BLEU-2: 0.6744, BLEU-3: 0.6744, BLEU-4: 0.6744
# ROUGE-1: 0.8434, ROUGE-2: 0.8395, ROUGE-L: 0.8434
# CIDEr: 0.0000
#
# Sample 497:
# BLEU-1: 0.7037, BLEU-2: 0.7037, BLEU-3: 0.7037, BLEU-4: 0.7037
# ROUGE-1: 0.8539, ROUGE-2: 0.8506, ROUGE-L: 0.8539
# CIDEr: 0.0000
#
# Sample 498:
# BLEU-1: 0.7788, BLEU-2: 0.7788, BLEU-3: 0.7788, BLEU-4: 0.7788
# ROUGE-1: 0.8889, ROUGE-2: 0.8870, ROUGE-L: 0.8889
# CIDEr: 0.0000
#
# Sample 499:
# BLEU-1: 0.4655, BLEU-2: 0.4655, BLEU-3: 0.4655, BLEU-4: 0.4655
# ROUGE-1: 0.7234, ROUGE-2: 0.7111, ROUGE-L: 0.7234
# CIDEr: 0.0000
#
# Sample 500:
# BLEU-1: 0.0743, BLEU-2: 0.0743, BLEU-3: 0.0743, BLEU-4: 0.0743
# ROUGE-1: 0.3810, ROUGE-2: 0.3158, ROUGE-L: 0.3810
# CIDEr: 0.0000

# %%
total_bleu = [0, 0, 0, 0]  # BLEU-1 to BLEU-4
total_rouge = {'rouge1': 0, 'rouge2': 0, 'rougeL': 0}
total_cider = 0

# %%
for ref, cand in zip(df1, df2):
    
    ref_tokens = ref.split()
    cand_tokens = cand.split()

    # Calculate BLEU scores
    bleu_1, bleu_2, bleu_3, bleu_4 = calculate_bleu(ref_tokens, cand_tokens)
    total_bleu[0] += bleu_1
    total_bleu[1] += bleu_2
    total_bleu[2] += bleu_3
    total_bleu[3] += bleu_4

    # Calculate ROUGE scores
    rouge_scores_sample = rouge_scorer_obj.score(ref, cand)
    total_rouge['rouge1'] += rouge_scores_sample['rouge1'].fmeasure
    total_rouge['rouge2'] += rouge_scores_sample['rouge2'].fmeasure
    total_rouge['rougeL'] += rouge_scores_sample['rougeL'].fmeasure

    # Calculate CIDEr scores
    cider_score, _ = cider_scorer.compute_score({0: [ref]}, {0: [cand]})
    total_cider += cider_score

# %%
num_samples = len(df1)

# Compute average BLEU, ROUGE, and CIDEr scores
average_bleu = [score / num_samples for score in total_bleu]
average_rouge = {key: score / num_samples for key, score in total_rouge.items()}
average_cider = total_cider / num_samples

print(f"Average BLEU-1: {average_bleu[0]:.4f}, BLEU-2: {average_bleu[1]:.4f}, BLEU-3: {average_bleu[2]:.4f}, BLEU-4: {average_bleu[3]:.4f}")
print(f"Average ROUGE-1: {average_rouge['rouge1']:.4f}, ROUGE-2: {average_rouge['rouge2']:.4f}, ROUGE-L: {average_rouge['rougeL']:.4f}")
print(f"Average CIDEr: {average_cider:.4f}")
# Out:
# Average BLEU-1: 0.4935, BLEU-2: 0.4935, BLEU-3: 0.4935, BLEU-4: 0.4935
# Average ROUGE-1: 0.7317, ROUGE-2: 0.7176, ROUGE-L: 0.7317
# Average CIDEr: 0.0000
